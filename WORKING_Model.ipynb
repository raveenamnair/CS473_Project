# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2021 NVIDIA Corporation
# Built on Sun_Feb_14_21:12:58_PST_2021
# Cuda compilation tools, release 11.2, V11.2.152
# Build cuda_11.2.r11.2/compiler.29618528_0

# %%
import os

# %%
CUSTOM_MODEL_NAME = 'erd_detection' 
PRETRAINED_MODEL_NAME = 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8'
PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz'
TF_RECORD_SCRIPT_NAME = 'generate_tfrecord.py'
LABEL_MAP_NAME = 'label_map.pbtxt'

# %%
paths = {
    'WORKSPACE_PATH': os.path.join('Tensorflow', 'workspace'),
    'SCRIPTS_PATH': os.path.join('Tensorflow','scripts'),
    'APIMODEL_PATH': os.path.join('Tensorflow','models'),
    'ANNOTATION_PATH': os.path.join('Tensorflow', 'workspace','annotations'),
    'IMAGE_PATH': os.path.join('Tensorflow', 'workspace','images'),
    'MODEL_PATH': os.path.join('Tensorflow', 'workspace','models'),
    'PRETRAINED_MODEL_PATH': os.path.join('Tensorflow', 'workspace','pre-trained-models'),
    'CHECKPOINT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME), 
    'OUTPUT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'export'), 
    'TFJS_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfjsexport'), 
    'TFLITE_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfliteexport'), 
    'PROTOC_PATH':os.path.join('Tensorflow','protoc')
 }

# %%
files = {
    'PIPELINE_CONFIG':os.path.join('Tensorflow', 'workspace','models', CUSTOM_MODEL_NAME, 'pipeline.config'),
    'TF_RECORD_SCRIPT': os.path.join(paths['SCRIPTS_PATH'], TF_RECORD_SCRIPT_NAME), 
    'LABELMAP': os.path.join(paths['ANNOTATION_PATH'], LABEL_MAP_NAME)
}

# %%
labels = ['entity', 'weak_entity', 'rel', 'ident_rel', 'rel_attr', 'many', 'one']

# %%
for path in paths.values():
    if not os.path.exists(path):
        if os.name == 'posix':
            # !mkdir -p {path}
        if os.name == 'nt':
            # !mkdir {path}

# %%
files
# Out:
# {'PIPELINE_CONFIG': 'Tensorflow/workspace/models/erd_detection/pipeline.config',
#  'TF_RECORD_SCRIPT': 'Tensorflow/scripts/generate_tfrecord.py',
#  'LABELMAP': 'Tensorflow/workspace/annotations/label_map.pbtxt'}

# %%
if os.name=='nt':
    # !pip install wget
    import wget

# %%
if not os.path.exists(os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection')):
    # !git clone https://github.com/tensorflow/models {paths['APIMODEL_PATH']}
# Out:
# Cloning into 'Tensorflow/models'...
# remote: Enumerating objects: 78535, done.
# remote: Counting objects: 100% (338/338), done.
# remote: Compressing objects: 100% (194/194), done.
# remote: Total 78535 (delta 164), reused 288 (delta 143), pack-reused 78197
# Receiving objects: 100% (78535/78535), 593.72 MiB | 38.58 MiB/s, done.
# Resolving deltas: 100% (55787/55787), done.

# %%
# Install Tensorflow Object Detection 
if os.name=='posix':  
    # !apt-get install protobuf-compiler
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && cp object_detection/packages/tf2/setup.py . && python -m pip install . 
    
if os.name=='nt':
    url="https://github.com/protocolbuffers/protobuf/releases/download/v3.15.6/protoc-3.15.6-win64.zip"
    wget.download(url)
    # !move protoc-3.15.6-win64.zip {paths['PROTOC_PATH']}
    # !cd {paths['PROTOC_PATH']} && tar -xf protoc-3.15.6-win64.zip
    os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin'))   
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py setup.py && python setup.py build && python setup.py install
    # !cd Tensorflow/models/research/slim && pip install -e .
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# protobuf-compiler is already the newest version (3.0.0-9.1ubuntu1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/Tensorflow/models/research
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# Collecting avro-python3
#   Downloading avro-python3-1.10.2.tar.gz (38 kB)
# Collecting apache-beam
#   Downloading apache_beam-2.42.0-cp37-cp37m-manylinux2010_x86_64.whl (11.0 MB)
#      |████████████████████████████████| 11.0 MB 8.4 MB/s
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (7.1.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (4.9.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (3.2.2)
# Requirement already satisfied: Cython in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (0.29.32)
# Requirement already satisfied: contextlib2 in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (0.5.5)
# Collecting tf-slim
#   Downloading tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
#      |████████████████████████████████| 352 kB 73.9 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.15.0)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (2.0.5)
# Collecting lvis
#   Downloading lvis-0.5.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.7.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.3.5)
# Collecting tf-models-official>=2.5.1
#   Downloading tf_models_official-2.10.0-py2.py3-none-any.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 45.0 MB/s
# Collecting tensorflow_io
#   Downloading tensorflow_io-0.27.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (25.0 MB)
#      |████████████████████████████████| 25.0 MB 1.5 MB/s
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (2.9.0)
# Collecting pyparsing==2.4.7
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 7.3 MB/s
# Collecting sacrebleu<=2.2.0
#   Downloading sacrebleu-2.2.0-py3-none-any.whl (116 kB)
#      |████████████████████████████████| 116 kB 78.1 MB/s
# Collecting portalocker
#   Downloading portalocker-2.6.0-py2.py3-none-any.whl (15 kB)
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (1.21.6)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.8.10)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2022.6.2)
# Collecting tensorflow-text~=2.10.0
#   Downloading tensorflow_text-2.10.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#      |████████████████████████████████| 5.9 MB 9.3 MB/s
# Requirement already satisfied: gin-config in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.5.0)
# Requirement already satisfied: psutil>=5.4.3 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.4.8)
# Requirement already satisfied: kaggle>=1.3.9 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.5.12)
# Collecting tensorflow-model-optimization>=0.4.1
#   Downloading tensorflow_model_optimization-0.7.3-py2.py3-none-any.whl (238 kB)
#      |████████████████████████████████| 238 kB 70.8 MB/s
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 2.3 MB/s
# Collecting immutabledict
#   Downloading immutabledict-2.2.2-py3-none-any.whl (4.0 kB)
# Collecting pyyaml<6.0,>=5.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 58.4 MB/s
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.6.0)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.1.3)
# Collecting tensorflow~=2.10.0
#   Downloading tensorflow-2.10.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (578.0 MB)
#      |████████████████████████████████| 578.0 MB 15 kB/s
# Collecting opencv-python-headless==4.5.2.52
#   Downloading opencv_python_headless-4.5.2.52-cp37-cp37m-manylinux2014_x86_64.whl (38.2 MB)
#      |████████████████████████████████| 38.2 MB 1.2 MB/s
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.12.0)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 51.1 MB/s
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.18.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 61.7 MB/s
# Requirement already satisfied: google-api-python-client>=1.6.7 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.12.11)
# Collecting py-cpuinfo>=3.3.0
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.17.4)
# Requirement already satisfied: google-auth<3dev,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.35.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.0.4)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.0.1)
# Requirement already satisfied: google-api-core<3dev,>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.31.6)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (21.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2022.5)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (57.4.0)
# Requirement already satisfied: protobuf<4.0.0dev,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.17.3)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.23.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.56.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.2.4)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2022.9.24)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2.8.2)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (6.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (4.64.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.24.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.0.4)
# Collecting tensorboard<2.11,>=2.10
#   Downloading tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
#      |████████████████████████████████| 5.9 MB 46.3 MB/s
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (3.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.6.3)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.14.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.3.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.1.2)
# Collecting tensorflow-estimator<2.11,>=2.10.0
#   Downloading tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
#      |████████████████████████████████| 438 kB 56.1 MB/s
# Collecting keras
#   Downloading keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 45.4 MB/s
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (4.1.1)
# Collecting flatbuffers>=2.0
#   Downloading flatbuffers-22.10.26-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (0.27.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (2.0.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (14.0.6)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.50.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.5.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.0.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (4.13.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (3.10.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (3.2.2)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official>=2.5.1->object-detection==0.1) (0.1.7)
# Collecting zstandard<1,>=0.18.0
#   Downloading zstandard-0.19.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.5 MB)
#      |████████████████████████████████| 2.5 MB 23.2 MB/s
# Requirement already satisfied: pyarrow<8.0.0,>=0.15.1 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (6.0.1)
# Collecting fastavro<2,>=0.23.6
#   Downloading fastavro-1.7.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#      |████████████████████████████████| 2.4 MB 65.4 MB/s
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (1.3.0)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (1.7)
# Collecting requests<3.0.0dev,>=2.18.0
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.7 MB/s
# Collecting dill<0.3.2,>=0.3.1.1
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      |████████████████████████████████| 151 kB 73.9 MB/s
# Collecting pymongo<4.0.0,>=3.8.0
#   Downloading pymongo-3.13.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (506 kB)
#      |████████████████████████████████| 506 kB 70.0 MB/s
# Collecting proto-plus<2,>=1.7.1
#   Downloading proto_plus-1.22.1-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 4.9 MB/s
# Collecting orjson<4.0
#   Downloading orjson-3.8.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (272 kB)
#      |████████████████████████████████| 272 kB 55.0 MB/s
# Collecting cloudpickle~=2.1.0
#   Downloading cloudpickle-2.1.0-py3-none-any.whl (25 kB)
# Collecting hdfs<3.0.0,>=2.1.0
#   Downloading hdfs-2.7.0-py3-none-any.whl (34 kB)
# Collecting docopt
#   Downloading docopt-0.6.2.tar.gz (25 kB)
# Collecting protobuf<4.0.0dev,>=3.12.0
#   Downloading protobuf-3.19.6-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 61.2 MB/s
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.1.1)
# Requirement already satisfied: kiwisolver>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (1.4.4)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (4.6.0.66)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (0.11.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.3)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.7/dist-packages (from seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.2.0)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons->tf-models-official>=2.5.1->object-detection==0.1) (2.7.1)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.10.2)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.8.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (2.3)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (5.10.0)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.10.0)
# Building wheels for collected packages: object-detection, dill, avro-python3, docopt, seqeval
#   Building wheel for object-detection (setup.py) ... done
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1696451 sha256=aaa3b6ee4f79f9750a07f750682db907289eedc3dc0a9a631de7f713549735c8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zak0zw9m/wheels/a9/26/bf/1cb2313ed4855917889b97658bf0a19999e3588e47867bdaee
#   Building wheel for dill (setup.py) ... done
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78544 sha256=27ba49c00d7ac3924a50f6600f6c7379811af30af2a70c9ff673d3f28534c466
#   Stored in directory: /root/.cache/pip/wheels/a4/61/fd/c57e374e580aa78a45ed78d5859b3a44436af17e22ca53284f
#   Building wheel for avro-python3 (setup.py) ... done
#   Created wheel for avro-python3: filename=avro_python3-1.10.2-py3-none-any.whl size=44010 sha256=dd3453fa82dd1cdddc4cacef098859fb93830d1b62cc972f02fa163f62d2570d
#   Stored in directory: /root/.cache/pip/wheels/d6/e5/b1/6b151d9b535ee50aaa6ab27d145a0104b6df02e5636f0376da
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=e381ccf653b76644b33c08c28cc146a1ba3250a9b68321236090af81f70a2246
#   Stored in directory: /root/.cache/pip/wheels/72/b0/3f/1d95f96ff986c7dfffe46ce2be4062f38ebd04b506c77c81b9
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16180 sha256=12112c12dbba3803c3dd46d33be56ffd99f6b1510b9fb64fd0e068bfb76cced0
#   Stored in directory: /root/.cache/pip/wheels/05/96/ee/7cac4e74f3b19e3158dce26a20a1c86b3533c43ec72a549fd7
# Successfully built object-detection dill avro-python3 docopt seqeval
# Installing collected packages: requests, pyparsing, protobuf, tensorflow-estimator, tensorboard, keras, flatbuffers, tensorflow, portalocker, docopt, dill, colorama, zstandard, tf-slim, tensorflow-text, tensorflow-model-optimization, tensorflow-addons, seqeval, sentencepiece, sacrebleu, pyyaml, pymongo, py-cpuinfo, proto-plus, orjson, opencv-python-headless, immutabledict, hdfs, fastavro, cloudpickle, tf-models-official, tensorflow-io, lvis, avro-python3, apache-beam, object-detection
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.17.3
#     Uninstalling protobuf-3.17.3:
#       Successfully uninstalled protobuf-3.17.3
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.9.0
#     Uninstalling tensorflow-estimator-2.9.0:
#       Successfully uninstalled tensorflow-estimator-2.9.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.9.1
#     Uninstalling tensorboard-2.9.1:
#       Successfully uninstalled tensorboard-2.9.1
#   Attempting uninstall: keras
#     Found existing installation: keras 2.9.0
#     Uninstalling keras-2.9.0:
#       Successfully uninstalled keras-2.9.0
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 1.12
#     Uninstalling flatbuffers-1.12:
#       Successfully uninstalled flatbuffers-1.12
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.9.2
#     Uninstalling tensorflow-2.9.2:
#       Successfully uninstalled tensorflow-2.9.2
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.6
#     Uninstalling dill-0.3.6:
#       Successfully uninstalled dill-0.3.6
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
#   Attempting uninstall: pymongo
#     Found existing installation: pymongo 4.3.2
#     Uninstalling pymongo-4.3.2:
#       Successfully uninstalled pymongo-4.3.2
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.6.0.66
#     Uninstalling opencv-python-headless-4.6.0.66:
#       Successfully uninstalled opencv-python-headless-4.6.0.66
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 1.5.0
#     Uninstalling cloudpickle-1.5.0:
#       Successfully uninstalled cloudpickle-1.5.0
# Successfully installed apache-beam-2.42.0 avro-python3-1.10.2 cloudpickle-2.1.0 colorama-0.4.6 dill-0.3.1.1 docopt-0.6.2 fastavro-1.7.0 flatbuffers-22.10.26 hdfs-2.7.0 immutabledict-2.2.2 keras-2.10.0 lvis-0.5.3 object-detection-0.1 opencv-python-headless-4.5.2.52 orjson-3.8.1 portalocker-2.6.0 proto-plus-1.22.1 protobuf-3.19.6 py-cpuinfo-9.0.0 pymongo-3.13.0 pyparsing-2.4.7 pyyaml-5.4.1 requests-2.28.1 sacrebleu-2.2.0 sentencepiece-0.1.97 seqeval-1.2.2 tensorboard-2.10.1 tensorflow-2.10.0 tensorflow-addons-0.18.0 tensorflow-estimator-2.10.0 tensorflow-io-0.27.0 tensorflow-model-optimization-0.7.3 tensorflow-text-2.10.0 tf-models-official-2.10.0 tf-slim-1.1.0 zstandard-0.19.0

# %%
VERIFICATION_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'builders', 'model_builder_tf2_test.py')
# Verify Installation
# !python {VERIFICATION_SCRIPT}
# Out:
# 2022-11-06 02:39:22.888048: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-06 02:39:23.063950: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-11-06 02:39:23.817439: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-11-06 02:39:23.817558: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-11-06 02:39:23.817579: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2022-11-06 02:39:25.686369: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-06 02:39:25.694971: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-06 02:39:25.695729: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# Running tests under Python 3.7.15: /usr/bin/python3
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2022-11-06 02:39:25.704382: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-06 02:39:25.704643: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-06 02:39:25.705569: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-06 02:39:25.706432: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-06 02:39:26.636931: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-06 02:39:26.637820: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-06 02:39:26.638451: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-06 02:39:26.638958: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2022-11-06 02:39:26.639006: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13735 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# W1106 02:39:26.989198 140508822779776 model_builder.py:1109] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 1.55s
# I1106 02:39:27.248912 140508822779776 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 1.55s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.51s
# I1106 02:39:27.757339 140508822779776 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.51s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.25s
# I1106 02:39:28.005078 140508822779776 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.25s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.35s
# I1106 02:39:28.358816 140508822779776 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.35s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 1.95s
# I1106 02:39:30.310793 140508822779776 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 1.95s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# [ RUN      ] ModelBuilderTF2Test.test_create_experimental_model
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# I1106 02:39:30.319685 140508822779776 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# [       OK ] ModelBuilderTF2Test.test_create_experimental_model
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.03s
# I1106 02:39:30.350657 140508822779776 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.03s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.01s
# I1106 02:39:30.365689 140508822779776 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.02s
# I1106 02:39:30.381637 140508822779776 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.09s
# I1106 02:39:30.474662 140508822779776 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.09s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.09s
# I1106 02:39:30.561394 140508822779776 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.09s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.09s
# I1106 02:39:30.655992 140508822779776 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.09s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.09s
# I1106 02:39:30.749958 140508822779776 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.09s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.1s
# I1106 02:39:30.849793 140508822779776 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.1s
# [       OK ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.03s
# I1106 02:39:30.878869 140508822779776 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.03s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# I1106 02:39:31.051302 140508822779776 ssd_efficientnet_bifpn_feature_extractor.py:151] EfficientDet EfficientNet backbone version: efficientnet-b0
# I1106 02:39:31.051472 140508822779776 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 64
# I1106 02:39:31.051542 140508822779776 ssd_efficientnet_bifpn_feature_extractor.py:154] EfficientDet BiFPN num iterations: 3
# I1106 02:39:31.053587 140508822779776 efficientnet_model.py:143] round_filter input=32 output=32
# I1106 02:39:31.083550 140508822779776 efficientnet_model.py:143] round_filter input=32 output=32
# I1106 02:39:31.083687 140508822779776 efficientnet_model.py:143] round_filter input=16 output=16
# I1106 02:39:31.159662 140508822779776 efficientnet_model.py:143] round_filter input=16 output=16
# I1106 02:39:31.159802 140508822779776 efficientnet_model.py:143] round_filter input=24 output=24
# I1106 02:39:31.368257 140508822779776 efficientnet_model.py:143] round_filter input=24 output=24
# I1106 02:39:31.368445 140508822779776 efficientnet_model.py:143] round_filter input=40 output=40
# I1106 02:39:31.562625 140508822779776 efficientnet_model.py:143] round_filter input=40 output=40
# I1106 02:39:31.562793 140508822779776 efficientnet_model.py:143] round_filter input=80 output=80
# I1106 02:39:31.857827 140508822779776 efficientnet_model.py:143] round_filter input=80 output=80
# I1106 02:39:31.858026 140508822779776 efficientnet_model.py:143] round_filter input=112 output=112
# I1106 02:39:32.293686 140508822779776 efficientnet_model.py:143] round_filter input=112 output=112
# I1106 02:39:32.293862 140508822779776 efficientnet_model.py:143] round_filter input=192 output=192
# I1106 02:39:32.662447 140508822779776 efficientnet_model.py:143] round_filter input=192 output=192
# I1106 02:39:32.662617 140508822779776 efficientnet_model.py:143] round_filter input=320 output=320
# I1106 02:39:32.753694 140508822779776 efficientnet_model.py:143] round_filter input=1280 output=1280
# I1106 02:39:32.795003 140508822779776 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.0, resolution=224, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1106 02:39:32.852696 140508822779776 ssd_efficientnet_bifpn_feature_extractor.py:151] EfficientDet EfficientNet backbone version: efficientnet-b1
# I1106 02:39:32.852849 140508822779776 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 88
# I1106 02:39:32.852922 140508822779776 ssd_efficientnet_bifpn_feature_extractor.py:154] EfficientDet BiFPN num iterations: 4
# I1106 02:39:32.854364 140508822779776 efficientnet_model.py:143] round_filter input=32 output=32
# I1106 02:39:32.872041 140508822779776 efficientnet_model.py:143] round_filter input=32 output=32
# I1106 02:39:32.872144 140508822779776 efficientnet_model.py:143] round_filter input=16 output=16
# I1106 02:39:33.014373 140508822779776 efficientnet_model.py:143] round_filter input=16 output=16
# I1106 02:39:33.014535 140508822779776 efficientnet_model.py:143] round_filter input=24 output=24
# I1106 02:39:33.269772 140508822779776 efficientnet_model.py:143] round_filter input=24 output=24
# I1106 02:39:33.269951 140508822779776 efficientnet_model.py:143] round_filter input=40 output=40
# I1106 02:39:33.522063 140508822779776 efficientnet_model.py:143] round_filter input=40 output=40
# I1106 02:39:33.522267 140508822779776 efficientnet_model.py:143] round_filter input=80 output=80
# I1106 02:39:33.888498 140508822779776 efficientnet_model.py:143] round_filter input=80 output=80
# I1106 02:39:33.888708 140508822779776 efficientnet_model.py:143] round_filter input=112 output=112
# I1106 02:39:34.244588 140508822779776 efficientnet_model.py:143] round_filter input=112 output=112
# I1106 02:39:34.244765 140508822779776 efficientnet_model.py:143] round_filter input=192 output=192
# I1106 02:39:34.693478 140508822779776 efficientnet_model.py:143] round_filter input=192 output=192
# I1106 02:39:34.693654 140508822779776 efficientnet_model.py:143] round_filter input=320 output=320
# I1106 02:39:34.879401 140508822779776 efficientnet_model.py:143] round_filter input=1280 output=1280
# I1106 02:39:34.914222 140508822779776 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.1, resolution=240, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1106 02:39:34.975712 140508822779776 ssd_efficientnet_bifpn_feature_extractor.py:151] EfficientDet EfficientNet backbone version: efficientnet-b2
# I1106 02:39:34.975880 140508822779776 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 112
# I1106 02:39:34.975962 140508822779776 ssd_efficientnet_bifpn_feature_extractor.py:154] EfficientDet BiFPN num iterations: 5
# I1106 02:39:34.977581 140508822779776 efficientnet_model.py:143] round_filter input=32 output=32
# I1106 02:39:34.995580 140508822779776 efficientnet_model.py:143] round_filter input=32 output=32
# I1106 02:39:34.995722 140508822779776 efficientnet_model.py:143] round_filter input=16 output=16
# I1106 02:39:35.133672 140508822779776 efficientnet_model.py:143] round_filter input=16 output=16
# I1106 02:39:35.133847 140508822779776 efficientnet_model.py:143] round_filter input=24 output=24
# I1106 02:39:35.450263 140508822779776 efficientnet_model.py:143] round_filter input=24 output=24
# I1106 02:39:35.450433 140508822779776 efficientnet_model.py:143] round_filter input=40 output=48
# I1106 02:39:35.725427 140508822779776 efficientnet_model.py:143] round_filter input=40 output=48
# I1106 02:39:35.725620 140508822779776 efficientnet_model.py:143] round_filter input=80 output=88
# I1106 02:39:36.134565 140508822779776 efficientnet_model.py:143] round_filter input=80 output=88
# I1106 02:39:36.134737 140508822779776 efficientnet_model.py:143] round_filter input=112 output=120
# I1106 02:39:36.501918 140508822779776 efficientnet_model.py:143] round_filter input=112 output=120
# I1106 02:39:36.502093 140508822779776 efficientnet_model.py:143] round_filter input=192 output=208
# I1106 02:39:37.010388 140508822779776 efficientnet_model.py:143] round_filter input=192 output=208
# I1106 02:39:37.010564 140508822779776 efficientnet_model.py:143] round_filter input=320 output=352
# I1106 02:39:37.197158 140508822779776 efficientnet_model.py:143] round_filter input=1280 output=1408
# I1106 02:39:37.237405 140508822779776 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.1, depth_coefficient=1.2, resolution=260, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1106 02:39:37.299446 140508822779776 ssd_efficientnet_bifpn_feature_extractor.py:151] EfficientDet EfficientNet backbone version: efficientnet-b3
# I1106 02:39:37.299610 140508822779776 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 160
# I1106 02:39:37.299683 140508822779776 ssd_efficientnet_bifpn_feature_extractor.py:154] EfficientDet BiFPN num iterations: 6
# I1106 02:39:37.301241 140508822779776 efficientnet_model.py:143] round_filter input=32 output=40
# I1106 02:39:37.321467 140508822779776 efficientnet_model.py:143] round_filter input=32 output=40
# I1106 02:39:37.321578 140508822779776 efficientnet_model.py:143] round_filter input=16 output=24
# I1106 02:39:37.477060 140508822779776 efficientnet_model.py:143] round_filter input=16 output=24
# I1106 02:39:37.477232 140508822779776 efficientnet_model.py:143] round_filter input=24 output=32
# I1106 02:39:37.752364 140508822779776 efficientnet_model.py:143] round_filter input=24 output=32
# I1106 02:39:37.752531 140508822779776 efficientnet_model.py:143] round_filter input=40 output=48
# I1106 02:39:38.210752 140508822779776 efficientnet_model.py:143] round_filter input=40 output=48
# I1106 02:39:38.210926 140508822779776 efficientnet_model.py:143] round_filter input=80 output=96
# I1106 02:39:38.673511 140508822779776 efficientnet_model.py:143] round_filter input=80 output=96
# I1106 02:39:38.673686 140508822779776 efficientnet_model.py:143] round_filter input=112 output=136
# I1106 02:39:39.141800 140508822779776 efficientnet_model.py:143] round_filter input=112 output=136
# I1106 02:39:39.141973 140508822779776 efficientnet_model.py:143] round_filter input=192 output=232
# I1106 02:39:39.684807 140508822779776 efficientnet_model.py:143] round_filter input=192 output=232
# I1106 02:39:39.684980 140508822779776 efficientnet_model.py:143] round_filter input=320 output=384
# I1106 02:39:39.874120 140508822779776 efficientnet_model.py:143] round_filter input=1280 output=1536
# I1106 02:39:39.913017 140508822779776 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.2, depth_coefficient=1.4, resolution=300, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1106 02:39:39.990771 140508822779776 ssd_efficientnet_bifpn_feature_extractor.py:151] EfficientDet EfficientNet backbone version: efficientnet-b4
# I1106 02:39:39.990944 140508822779776 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 224
# I1106 02:39:39.991019 140508822779776 ssd_efficientnet_bifpn_feature_extractor.py:154] EfficientDet BiFPN num iterations: 7
# I1106 02:39:39.992601 140508822779776 efficientnet_model.py:143] round_filter input=32 output=48
# I1106 02:39:40.013217 140508822779776 efficientnet_model.py:143] round_filter input=32 output=48
# I1106 02:39:40.013326 140508822779776 efficientnet_model.py:143] round_filter input=16 output=24
# I1106 02:39:40.156911 140508822779776 efficientnet_model.py:143] round_filter input=16 output=24
# I1106 02:39:40.157080 140508822779776 efficientnet_model.py:143] round_filter input=24 output=32
# I1106 02:39:40.517325 140508822779776 efficientnet_model.py:143] round_filter input=24 output=32
# I1106 02:39:40.517513 140508822779776 efficientnet_model.py:143] round_filter input=40 output=56
# I1106 02:39:40.885167 140508822779776 efficientnet_model.py:143] round_filter input=40 output=56
# I1106 02:39:40.885357 140508822779776 efficientnet_model.py:143] round_filter input=80 output=112
# I1106 02:39:41.429796 140508822779776 efficientnet_model.py:143] round_filter input=80 output=112
# I1106 02:39:41.429974 140508822779776 efficientnet_model.py:143] round_filter input=112 output=160
# I1106 02:39:41.972784 140508822779776 efficientnet_model.py:143] round_filter input=112 output=160
# I1106 02:39:41.972965 140508822779776 efficientnet_model.py:143] round_filter input=192 output=272
# I1106 02:39:42.707451 140508822779776 efficientnet_model.py:143] round_filter input=192 output=272
# I1106 02:39:42.707633 140508822779776 efficientnet_model.py:143] round_filter input=320 output=448
# I1106 02:39:42.890549 140508822779776 efficientnet_model.py:143] round_filter input=1280 output=1792
# I1106 02:39:42.926646 140508822779776 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.4, depth_coefficient=1.8, resolution=380, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1106 02:39:43.003762 140508822779776 ssd_efficientnet_bifpn_feature_extractor.py:151] EfficientDet EfficientNet backbone version: efficientnet-b5
# I1106 02:39:43.003926 140508822779776 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 288
# I1106 02:39:43.004002 140508822779776 ssd_efficientnet_bifpn_feature_extractor.py:154] EfficientDet BiFPN num iterations: 7
# I1106 02:39:43.005569 140508822779776 efficientnet_model.py:143] round_filter input=32 output=48
# I1106 02:39:43.031119 140508822779776 efficientnet_model.py:143] round_filter input=32 output=48
# I1106 02:39:43.031316 140508822779776 efficientnet_model.py:143] round_filter input=16 output=24
# I1106 02:39:43.261811 140508822779776 efficientnet_model.py:143] round_filter input=16 output=24
# I1106 02:39:43.261989 140508822779776 efficientnet_model.py:143] round_filter input=24 output=40
# I1106 02:39:43.696684 140508822779776 efficientnet_model.py:143] round_filter input=24 output=40
# I1106 02:39:43.696866 140508822779776 efficientnet_model.py:143] round_filter input=40 output=64
# I1106 02:39:44.187691 140508822779776 efficientnet_model.py:143] round_filter input=40 output=64
# I1106 02:39:44.187870 140508822779776 efficientnet_model.py:143] round_filter input=80 output=128
# I1106 02:39:45.025125 140508822779776 efficientnet_model.py:143] round_filter input=80 output=128
# I1106 02:39:45.025329 140508822779776 efficientnet_model.py:143] round_filter input=112 output=176
# I1106 02:39:45.663114 140508822779776 efficientnet_model.py:143] round_filter input=112 output=176
# I1106 02:39:45.663299 140508822779776 efficientnet_model.py:143] round_filter input=192 output=304
# I1106 02:39:46.484467 140508822779776 efficientnet_model.py:143] round_filter input=192 output=304
# I1106 02:39:46.484636 140508822779776 efficientnet_model.py:143] round_filter input=320 output=512
# I1106 02:39:46.768929 140508822779776 efficientnet_model.py:143] round_filter input=1280 output=2048
# I1106 02:39:46.810183 140508822779776 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.6, depth_coefficient=2.2, resolution=456, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1106 02:39:46.893622 140508822779776 ssd_efficientnet_bifpn_feature_extractor.py:151] EfficientDet EfficientNet backbone version: efficientnet-b6
# I1106 02:39:46.893783 140508822779776 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 384
# I1106 02:39:46.893858 140508822779776 ssd_efficientnet_bifpn_feature_extractor.py:154] EfficientDet BiFPN num iterations: 8
# I1106 02:39:46.895465 140508822779776 efficientnet_model.py:143] round_filter input=32 output=56
# I1106 02:39:46.915421 140508822779776 efficientnet_model.py:143] round_filter input=32 output=56
# I1106 02:39:46.915544 140508822779776 efficientnet_model.py:143] round_filter input=16 output=32
# I1106 02:39:47.145709 140508822779776 efficientnet_model.py:143] round_filter input=16 output=32
# I1106 02:39:47.145891 140508822779776 efficientnet_model.py:143] round_filter input=24 output=40
# I1106 02:39:47.688307 140508822779776 efficientnet_model.py:143] round_filter input=24 output=40
# I1106 02:39:47.688486 140508822779776 efficientnet_model.py:143] round_filter input=40 output=72
# I1106 02:39:48.230469 140508822779776 efficientnet_model.py:143] round_filter input=40 output=72
# I1106 02:39:48.230642 140508822779776 efficientnet_model.py:143] round_filter input=80 output=144
# I1106 02:39:48.943300 140508822779776 efficientnet_model.py:143] round_filter input=80 output=144
# I1106 02:39:48.943481 140508822779776 efficientnet_model.py:143] round_filter input=112 output=200
# I1106 02:39:49.676122 140508822779776 efficientnet_model.py:143] round_filter input=112 output=200
# I1106 02:39:49.676309 140508822779776 efficientnet_model.py:143] round_filter input=192 output=344
# I1106 02:39:50.705486 140508822779776 efficientnet_model.py:143] round_filter input=192 output=344
# I1106 02:39:50.705665 140508822779776 efficientnet_model.py:143] round_filter input=320 output=576
# I1106 02:39:50.980132 140508822779776 efficientnet_model.py:143] round_filter input=1280 output=2304
# I1106 02:39:51.018136 140508822779776 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1106 02:39:51.112853 140508822779776 ssd_efficientnet_bifpn_feature_extractor.py:151] EfficientDet EfficientNet backbone version: efficientnet-b7
# I1106 02:39:51.113018 140508822779776 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 384
# I1106 02:39:51.113094 140508822779776 ssd_efficientnet_bifpn_feature_extractor.py:154] EfficientDet BiFPN num iterations: 8
# I1106 02:39:51.114635 140508822779776 efficientnet_model.py:143] round_filter input=32 output=64
# I1106 02:39:51.134593 140508822779776 efficientnet_model.py:143] round_filter input=32 output=64
# I1106 02:39:51.134736 140508822779776 efficientnet_model.py:143] round_filter input=16 output=32
# I1106 02:39:51.437115 140508822779776 efficientnet_model.py:143] round_filter input=16 output=32
# I1106 02:39:51.437309 140508822779776 efficientnet_model.py:143] round_filter input=24 output=48
# I1106 02:39:52.305739 140508822779776 efficientnet_model.py:143] round_filter input=24 output=48
# I1106 02:39:52.305918 140508822779776 efficientnet_model.py:143] round_filter input=40 output=80
# I1106 02:39:52.926321 140508822779776 efficientnet_model.py:143] round_filter input=40 output=80
# I1106 02:39:52.926507 140508822779776 efficientnet_model.py:143] round_filter input=80 output=160
# I1106 02:39:53.843703 140508822779776 efficientnet_model.py:143] round_filter input=80 output=160
# I1106 02:39:53.843874 140508822779776 efficientnet_model.py:143] round_filter input=112 output=224
# I1106 02:39:54.751860 140508822779776 efficientnet_model.py:143] round_filter input=112 output=224
# I1106 02:39:54.752036 140508822779776 efficientnet_model.py:143] round_filter input=192 output=384
# I1106 02:39:55.897031 140508822779776 efficientnet_model.py:143] round_filter input=192 output=384
# I1106 02:39:55.897222 140508822779776 efficientnet_model.py:143] round_filter input=320 output=640
# I1106 02:39:56.262064 140508822779776 efficientnet_model.py:143] round_filter input=1280 output=2560
# I1106 02:39:56.318323 140508822779776 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 25.55s
# I1106 02:39:56.431871 140508822779776 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 25.55s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# I1106 02:39:56.460337 140508822779776 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I1106 02:39:56.462275 140508822779776 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I1106 02:39:56.462779 140508822779776 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I1106 02:39:56.464133 140508822779776 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I1106 02:39:56.465396 140508822779776 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I1106 02:39:56.465812 140508822779776 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I1106 02:39:56.466808 140508822779776 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 30.767s
#
# OK (skipped=1)

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ----------------------
# absl-py                       1.3.0
# aeppl                         0.0.33
# aesara                        2.7.9
# aiohttp                       3.8.3
# aiosignal                     1.2.0
# alabaster                     0.7.12
# albumentations                1.2.1
# altair                        4.2.0
# apache-beam                   2.42.0
# appdirs                       1.4.4
# arviz                         0.12.1
# astor                         0.8.1
# astropy                       4.3.1
# astunparse                    1.6.3
# async-timeout                 4.0.2
# asynctest                     0.13.0
# atari-py                      0.2.9
# atomicwrites                  1.4.1
# attrs                         22.1.0
# audioread                     3.0.0
# autograd                      1.5
# avro-python3                  1.10.2
# Babel                         2.10.3
# backcall                      0.2.0
# beautifulsoup4                4.6.3
# bleach                        5.0.1
# blis                          0.7.9
# bokeh                         2.3.3
# branca                        0.5.0
# bs4                           0.0.1
# CacheControl                  0.12.11
# cached-property               1.5.2
# cachetools                    4.2.4
# catalogue                     2.0.8
# certifi                       2022.9.24
# cffi                          1.15.1
# cftime                        1.6.2
# chardet                       3.0.4
# charset-normalizer            2.1.1
# click                         7.1.2
# clikit                        0.6.2
# cloudpickle                   2.1.0
# cmake                         3.22.6
# cmdstanpy                     1.0.8
# colorama                      0.4.6
# colorcet                      3.0.1
# colorlover                    0.3.0
# community                     1.0.0b1
# confection                    0.0.3
# cons                          0.4.5
# contextlib2                   0.5.5
# convertdate                   2.4.0
# crashtest                     0.3.1
# crcmod                        1.7
# cufflinks                     0.17.3
# cupy-cuda11x                  11.0.0
# cvxopt                        1.3.0
# cvxpy                         1.2.1
# cycler                        0.11.0
# cymem                         2.0.7
# Cython                        0.29.32
# daft                          0.0.4
# dask                          2022.2.0
# datascience                   0.17.5
# debugpy                       1.0.0
# decorator                     4.4.2
# defusedxml                    0.7.1
# descartes                     1.1.0
# dill                          0.3.1.1
# distributed                   2022.2.0
# dlib                          19.24.0
# dm-tree                       0.1.7
# dnspython                     2.2.1
# docopt                        0.6.2
# docutils                      0.17.1
# dopamine-rl                   1.0.5
# earthengine-api               0.1.329
# easydict                      1.10
# ecos                          2.0.10
# editdistance                  0.5.3
# en-core-web-sm                3.4.1
# entrypoints                   0.4
# ephem                         4.1.3
# et-xmlfile                    1.1.0
# etils                         0.8.0
# etuples                       0.3.8
# fa2                           0.3.5
# fastai                        2.7.9
# fastavro                      1.7.0
# fastcore                      1.5.27
# fastdownload                  0.0.7
# fastdtw                       0.3.4
# fastjsonschema                2.16.2
# fastprogress                  1.0.3
# fastrlock                     0.8
# feather-format                0.4.1
# filelock                      3.8.0
# firebase-admin                4.4.0
# fix-yahoo-finance             0.0.22
# Flask                         1.1.4
# flatbuffers                   22.10.26
# folium                        0.12.1.post1
# frozenlist                    1.3.1
# fsspec                        2022.10.0
# future                        0.16.0
# gast                          0.4.0
# GDAL                          2.2.2
# gdown                         4.4.0
# gensim                        3.6.0
# geographiclib                 1.52
# geopy                         1.17.0
# gin-config                    0.5.0
# glob2                         0.7
# google                        2.0.3
# google-api-core               1.31.6
# google-api-python-client      1.12.11
# google-auth                   1.35.0
# google-auth-httplib2          0.0.4
# google-auth-oauthlib          0.4.6
# google-cloud-bigquery         1.21.0
# google-cloud-bigquery-storage 1.1.2
# google-cloud-core             1.0.3
# google-cloud-datastore        1.8.0
# google-cloud-firestore        1.7.0
# google-cloud-language         1.2.0
# google-cloud-storage          1.18.1
# google-cloud-translate        1.5.0
# google-colab                  1.0.0
# google-pasta                  0.2.0
# google-resumable-media        0.4.1
# googleapis-common-protos      1.56.4
# googledrivedownloader         0.4
# graphviz                      0.10.1
# greenlet                      1.1.3.post0
# grpcio                        1.50.0
# gspread                       3.4.2
# gspread-dataframe             3.0.8
# gym                           0.25.2
# gym-notices                   0.0.8
# h5py                          3.1.0
# hdfs                          2.7.0
# HeapDict                      1.0.1
# hijri-converter               2.2.4
# holidays                      0.16
# holoviews                     1.14.9
# html5lib                      1.0.1
# httpimport                    0.5.18
# httplib2                      0.17.4
# httplib2shim                  0.0.3
# httpstan                      4.6.1
# humanize                      0.5.1
# hyperopt                      0.1.2
# idna                          2.10
# imageio                       2.9.0
# imagesize                     1.4.1
# imbalanced-learn              0.8.1
# imblearn                      0.0
# imgaug                        0.4.0
# immutabledict                 2.2.2
# importlib-metadata            4.13.0
# importlib-resources           5.10.0
# imutils                       0.5.4
# inflect                       2.1.0
# intel-openmp                  2022.2.0
# intervaltree                  2.1.0
# ipykernel                     5.3.4
# ipython                       7.9.0
# ipython-genutils              0.2.0
# ipython-sql                   0.3.9
# ipywidgets                    7.7.1
# itsdangerous                  1.1.0
# jax                           0.3.23
# jaxlib                        0.3.22+cuda11.cudnn805
# jieba                         0.42.1
# Jinja2                        2.11.3
# joblib                        1.2.0
# jpeg4py                       0.1.4
# jsonschema                    4.3.3
# jupyter-client                6.1.12
# jupyter-console               6.1.0
# jupyter-core                  4.11.2
# jupyterlab-widgets            3.0.3
# kaggle                        1.5.12
# kapre                         0.3.7
# keras                         2.10.0
# Keras-Preprocessing           1.1.2
# keras-vis                     0.4.1
# kiwisolver                    1.4.4
# korean-lunar-calendar         0.3.1
# langcodes                     3.3.0
# libclang                      14.0.6
# librosa                       0.8.1
# lightgbm                      2.2.3
# llvmlite                      0.39.1
# lmdb                          0.99
# locket                        1.0.0
# logical-unification           0.4.5
# LunarCalendar                 0.0.9
# lvis                          0.5.3
# lxml                          4.9.1
# Markdown                      3.4.1
# MarkupSafe                    2.0.1
# marshmallow                   3.18.0
# matplotlib                    3.2.2
# matplotlib-venn               0.11.7
# miniKanren                    1.0.3
# missingno                     0.5.1
# mistune                       0.8.4
# mizani                        0.7.3
# mkl                           2019.0
# mlxtend                       0.14.0
# more-itertools                9.0.0
# moviepy                       0.2.3.5
# mpmath                        1.2.1
# msgpack                       1.0.4
# multidict                     6.0.2
# multipledispatch              0.6.0
# multitasking                  0.0.11
# murmurhash                    1.0.9
# music21                       5.5.0
# natsort                       5.5.0
# nbconvert                     5.6.1
# nbformat                      5.7.0
# netCDF4                       1.6.1
# networkx                      2.6.3
# nibabel                       3.0.2
# nltk                          3.7
# notebook                      5.5.0
# numba                         0.56.3
# numexpr                       2.8.4
# numpy                         1.21.6
# oauth2client                  4.1.3
# oauthlib                      3.2.2
# object-detection              0.1
# okgrade                       0.4.3
# opencv-contrib-python         4.6.0.66
# opencv-python                 4.6.0.66
# opencv-python-headless        4.5.2.52
# openpyxl                      3.0.10
# opt-einsum                    3.3.0
# orjson                        3.8.1
# osqp                          0.6.2.post0
# packaging                     21.3
# palettable                    3.3.0
# pandas                        1.3.5
# pandas-datareader             0.9.0
# pandas-gbq                    0.13.3
# pandas-profiling              1.4.1
# pandocfilters                 1.5.0
# panel                         0.12.1
# param                         1.12.2
# parso                         0.8.3
# partd                         1.3.0
# pastel                        0.2.1
# pathlib                       1.0.1
# pathy                         0.6.2
# patsy                         0.5.3
# pep517                        0.13.0
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        7.1.2
# pip                           21.1.3
# pip-tools                     6.2.0
# plotly                        5.5.0
# plotnine                      0.8.0
# pluggy                        0.7.1
# pooch                         1.6.0
# portalocker                   2.6.0
# portpicker                    1.3.9
# prefetch-generator            1.0.1
# preshed                       3.0.8
# prettytable                   3.4.1
# progressbar2                  3.38.0
# promise                       2.3
# prompt-toolkit                2.0.10
# prophet                       1.1.1
# proto-plus                    1.22.1
# protobuf                      3.19.6
# psutil                        5.4.8
# psycopg2                      2.9.5
# ptyprocess                    0.7.0
# py                            1.11.0
# py-cpuinfo                    9.0.0
# pyarrow                       6.0.1
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycocotools                   2.0.5
# pycparser                     2.21
# pyct                          0.4.8
# pydantic                      1.10.2
# pydata-google-auth            1.4.0
# pydot                         1.3.0
# pydot-ng                      2.0.0
# pydotplus                     2.0.2
# PyDrive                       1.3.1
# pyemd                         0.5.1
# pyerfa                        2.0.0.1
# Pygments                      2.6.1
# pygobject                     3.26.1
# pylev                         1.4.0
# pymc                          4.1.4
# PyMeeus                       0.5.11
# pymongo                       3.13.0
# pymystem3                     0.2.0
# PyOpenGL                      3.1.6
# pyparsing                     2.4.7
# pyrsistent                    0.18.1
# pysimdjson                    3.2.0
# pysndfile                     1.3.8
# PySocks                       1.7.1
# pystan                        3.3.0
# pytest                        3.6.4
# python-apt                    0.0.0
# python-dateutil               2.8.2
# python-louvain                0.16
# python-slugify                6.1.2
# python-utils                  3.3.3
# pytz                          2022.5
# pyviz-comms                   2.2.1
# PyWavelets                    1.3.0
# PyYAML                        5.4.1
# pyzmq                         23.2.1
# qdldl                         0.1.5.post2
# qudida                        0.0.4
# regex                         2022.6.2
# requests                      2.28.1
# requests-oauthlib             1.3.1
# resampy                       0.4.2
# rpy2                          3.5.5
# rsa                           4.9
# sacrebleu                     2.2.0
# scikit-image                  0.18.3
# scikit-learn                  1.0.2
# scipy                         1.7.3
# screen-resolution-extra       0.0.0
# scs                           3.2.0
# seaborn                       0.11.2
# Send2Trash                    1.8.0
# sentencepiece                 0.1.97
# seqeval                       1.2.2
# setuptools                    57.4.0
# setuptools-git                1.2
# Shapely                       1.8.5.post1
# six                           1.15.0
# sklearn-pandas                1.8.0
# smart-open                    5.2.1
# snowballstemmer               2.2.0
# sortedcontainers              2.4.0
# soundfile                     0.11.0
# spacy                         3.4.2
# spacy-legacy                  3.0.10
# spacy-loggers                 1.0.3
# Sphinx                        1.8.6
# sphinxcontrib-serializinghtml 1.1.5
# sphinxcontrib-websupport      1.2.4
# SQLAlchemy                    1.4.42
# sqlparse                      0.4.3
# srsly                         2.4.5
# statsmodels                   0.12.2
# sympy                         1.7.1
# tables                        3.7.0
# tabulate                      0.8.10
# tblib                         1.7.0
# tenacity                      8.1.0
# tensorboard                   2.10.1
# tensorboard-data-server       0.6.1
# tensorboard-plugin-wit        1.8.1
# tensorflow                    2.10.0
# tensorflow-addons             0.18.0
# tensorflow-datasets           4.6.0
# tensorflow-estimator          2.10.0
# tensorflow-gcs-config         2.9.1
# tensorflow-hub                0.12.0
# tensorflow-io                 0.27.0
# tensorflow-io-gcs-filesystem  0.27.0
# tensorflow-metadata           1.10.0
# tensorflow-model-optimization 0.7.3
# tensorflow-probability        0.16.0
# tensorflow-text               2.10.0
# termcolor                     2.0.1
# terminado                     0.13.3
# testpath                      0.6.0
# text-unidecode                1.3
# textblob                      0.15.3
# tf-models-official            2.10.0
# tf-slim                       1.1.0
# thinc                         8.1.5
# threadpoolctl                 3.1.0
# tifffile                      2021.11.2
# toml                          0.10.2
# tomli                         2.0.1
# toolz                         0.12.0
# torch                         1.12.1+cu113
# torchaudio                    0.12.1+cu113
# torchsummary                  1.5.1
# torchtext                     0.13.1
# torchvision                   0.13.1+cu113
# tornado                       5.1.1
# tqdm                          4.64.1
# traitlets                     5.1.1
# tweepy                        3.10.0
# typeguard                     2.7.1
# typer                         0.4.2
# typing-extensions             4.1.1
# tzlocal                       1.5.1
# uritemplate                   3.0.1
# urllib3                       1.24.3
# vega-datasets                 0.9.0
# wasabi                        0.10.1
# wcwidth                       0.2.5
# webargs                       8.2.0
# webencodings                  0.5.1
# Werkzeug                      1.0.1
# wheel                         0.37.1
# widgetsnbextension            3.6.1
# wordcloud                     1.8.2.2
# wrapt                         1.14.1
# xarray                        0.20.2
# xarray-einstats               0.2.2
# xgboost                       0.90
# xkit                          0.0.0
# xlrd                          1.1.0
# xlwt                          1.3.0
# yarl                          1.8.1
# yellowbrick                   1.5
# zict                          2.2.0
# zipp                          3.10.0
# zstandard                     0.19.0

# %%
import object_detection

# %%
if os.name =='posix':
    # !wget {PRETRAINED_MODEL_URL}
    # !mv {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
if os.name == 'nt':
    wget.download(PRETRAINED_MODEL_URL)
    # !move {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
# Out:
# --2022-11-06 02:41:09--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 172.217.193.128, 2607:f8b0:400c:c03::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|172.217.193.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20515344 (20M) [application/x-tar]
# Saving to: ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’
#
# ssd_mobilenet_v2_fp 100%[===================>]  19.56M  --.-KB/s    in 0.1s
#
# 2022-11-06 02:41:09 (184 MB/s) - ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’ saved [20515344/20515344]
#
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/checkpoint
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.index
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/saved_model.pb
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.index

# %%
labels = [{'name':'entity', 'id':1}, {'name':'weak_entity', 'id':2}, {'name':'rel', 'id':3}, {'name':'ident_rel', 'id':4}, {'name': 'rel_attr', 'id':5}, {'name': 'many', 'id':6}, {'name': 'one', 'id':7}]
with open(files['LABELMAP'], 'w') as f:
    for label in labels:
        f.write('item { \n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %%
if not os.path.exists(files['TF_RECORD_SCRIPT']):
    # !git clone https://github.com/nicknochnack/GenerateTFRecord {paths['SCRIPTS_PATH']}
# Out:
# Cloning into 'Tensorflow/scripts'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 1 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.

# %%
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'train')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'train.record')} 
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'test')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'test.record')}
# Out:
# 2022-11-06 02:46:25.265816: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Successfully created the TFRecord file: Tensorflow/workspace/annotations/train.record
# 2022-11-06 02:46:28.774375: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Successfully created the TFRecord file: Tensorflow/workspace/annotations/test.record

# %%
if os.name =='posix':
    # !cp {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
if os.name == 'nt':
    # !copy {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
config = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])

# %%
config
# Out:
# {'model': ssd {
#    num_classes: 90
#    image_resizer {
#      fixed_shape_resizer {
#        height: 320
#        width: 320
#      }
#    }
#    feature_extractor {
#      type: "ssd_mobilenet_v2_fpn_keras"
#      depth_multiplier: 1.0
#      min_depth: 16
#      conv_hyperparams {
#        regularizer {
#          l2_regularizer {
#            weight: 3.9999998989515007e-05
#          }
#        }
#        initializer {
#          random_normal_initializer {
#            mean: 0.0
#            stddev: 0.009999999776482582
#          }
#        }
#        activation: RELU_6
#        batch_norm {
#          decay: 0.996999979019165
#          scale: true
#          epsilon: 0.0010000000474974513
#        }
#      }
#      use_depthwise: true
#      override_base_feature_extractor_hyperparams: true
#      fpn {
#        min_level: 3
#        max_level: 7
#        additional_layer_depth: 128
#      }
#    }
#    box_coder {
#      faster_rcnn_box_coder {
#        y_scale: 10.0
#        x_scale: 10.0
#        height_scale: 5.0
#        width_scale: 5.0
#      }
#    }
#    matcher {
#      argmax_matcher {
#        matched_threshold: 0.5
#        unmatched_threshold: 0.5
#        ignore_thresholds: false
#        negatives_lower_than_unmatched: true
#        force_match_for_each_row: true
#        use_matmul_gather: true
#      }
#    }
#    similarity_calculator {
#      iou_similarity {
#      }
#    }
#    box_predictor {
#      weight_shared_convolutional_box_predictor {
#        conv_hyperparams {
#          regularizer {
#            l2_regularizer {
#              weight: 3.9999998989515007e-05
#            }
#          }
#          initializer {
#            random_normal_initializer {
#              mean: 0.0
#              stddev: 0.009999999776482582
#            }
#          }
#          activation: RELU_6
#          batch_norm {
#            decay: 0.996999979019165
#            scale: true
#            epsilon: 0.0010000000474974513
#          }
#        }
#        depth: 128
#        num_layers_before_predictor: 4
#        kernel_size: 3
#        class_prediction_bias_init: -4.599999904632568
#        share_prediction_tower: true
#        use_depthwise: true
#      }
#    }
#    anchor_generator {
#      multiscale_anchor_generator {
#        min_level: 3
#        max_level: 7
#        anchor_scale: 4.0
#        aspect_ratios: 1.0
#        aspect_ratios: 2.0
#        aspect_ratios: 0.5
#        scales_per_octave: 2
#      }
#    }
#    post_processing {
#      batch_non_max_suppression {
#        score_threshold: 9.99999993922529e-09
#        iou_threshold: 0.6000000238418579
#        max_detections_per_class: 100
#        max_total_detections: 100
#        use_static_shapes: false
#      }
#      score_converter: SIGMOID
#    }
#    normalize_loss_by_num_matches: true
#    loss {
#      localization_loss {
#        weighted_smooth_l1 {
#        }
#      }
#      classification_loss {
#        weighted_sigmoid_focal {
#          gamma: 2.0
#          alpha: 0.25
#        }
#      }
#      classification_weight: 1.0
#      localization_weight: 1.0
#    }
#    encode_background_as_zeros: true
#    normalize_loc_loss_by_codesize: true
#    inplace_batchnorm_update: true
#    freeze_batchnorm: false
#  }, 'train_config': batch_size: 128
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  data_augmentation_options {
#    random_crop_image {
#      min_object_covered: 0.0
#      min_aspect_ratio: 0.75
#      max_aspect_ratio: 3.0
#      min_area: 0.75
#      max_area: 1.0
#      overlap_thresh: 0.0
#    }
#  }
#  sync_replicas: true
#  optimizer {
#    momentum_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.07999999821186066
#          total_steps: 50000
#          warmup_learning_rate: 0.026666000485420227
#          warmup_steps: 1000
#        }
#      }
#      momentum_optimizer_value: 0.8999999761581421
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "PATH_TO_BE_CONFIGURED"
#  num_steps: 50000
#  startup_delay_steps: 0.0
#  replicas_to_aggregate: 8
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "classification"
#  fine_tune_checkpoint_version: V2, 'train_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }, 'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false, 'eval_input_configs': [label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }
#  ], 'eval_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }}

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.ssd.num_classes = len(labels)
pipeline_config.train_config.batch_size = 4
pipeline_config.train_config.fine_tune_checkpoint = os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'checkpoint', 'ckpt-0')
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= files['LABELMAP']
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'train.record')]
pipeline_config.eval_input_reader[0].label_map_path = files['LABELMAP']
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'test.record')]

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %%
TRAINING_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'model_main_tf2.py')

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --num_train_steps=2000".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'])

# %%
print(command)
# Out:
# python Tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=Tensorflow/workspace/models/erd_detection --pipeline_config_path=Tensorflow/workspace/models/erd_detection/pipeline.config --num_train_steps=2000

# %%
# !{command}
# Out:
# 2022-11-06 02:58:44.380346: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-11-06 02:58:45.149114: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-11-06 02:58:45.149237: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-11-06 02:58:45.149258: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2022-11-06 02:58:48.276796: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I1106 02:58:48.294876 140130084312960 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 2000
# I1106 02:58:48.299837 140130084312960 config_util.py:552] Maybe overwriting train_steps: 2000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I1106 02:58:48.300009 140130084312960 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/model_lib_v2.py:564: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W1106 02:58:48.327654 140130084312960 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/object_detection/model_lib_v2.py:564: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['Tensorflow/workspace/annotations/train.record']
# I1106 02:58:48.336155 140130084312960 dataset_builder.py:162] Reading unweighted datasets: ['Tensorflow/workspace/annotations/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['Tensorflow/workspace/annotations/train.record']
# I1106 02:58:48.336366 140130084312960 dataset_builder.py:79] Reading record datasets for input file: ['Tensorflow/workspace/annotations/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I1106 02:58:48.336472 140130084312960 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W1106 02:58:48.336541 140130084312960 dataset_builder.py:87] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:104: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W1106 02:58:48.342801 140130084312960 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:104: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W1106 02:58:48.358405 140130084312960 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W1106 02:58:55.006651 140130084312960 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W1106 02:58:57.834225 140130084312960 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1106 02:58:59.399248 140130084312960 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# 2022-11-06 02:59:02.441436: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 42476400 exceeds 10% of free system memory.
# 2022-11-06 02:59:02.443709: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 17465760 exceeds 10% of free system memory.
# 2022-11-06 02:59:02.585847: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 36105168 exceeds 10% of free system memory.
# 2022-11-06 02:59:02.680029: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 35564208 exceeds 10% of free system memory.
# 2022-11-06 02:59:02.741798: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 25456896 exceeds 10% of free system memory.
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   "`tf.keras.backend.set_learning_phase` is deprecated and "
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1106 02:59:35.752849 140130084312960 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1106 02:59:35.755861 140130084312960 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1106 02:59:35.758555 140130084312960 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1106 02:59:35.759552 140130084312960 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1106 02:59:35.762736 140130084312960 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1106 02:59:35.763714 140130084312960 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1106 02:59:35.767033 140130084312960 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1106 02:59:35.767989 140130084312960 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1106 02:59:35.770526 140130084312960 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1106 02:59:35.771487 140130084312960 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W1106 02:59:36.825798 140125640038144 deprecation.py:560] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# INFO:tensorflow:Step 100 per-step time 0.933s
# I1106 03:01:09.789789 140130084312960 model_lib_v2.py:707] Step 100 per-step time 0.933s
# INFO:tensorflow:{'Loss/classification_loss': 0.44066486,
#  'Loss/localization_loss': 0.5322793,
#  'Loss/regularization_loss': 0.15339395,
#  'Loss/total_loss': 1.1263381,
#  'learning_rate': 0.0319994}
# I1106 03:01:09.791587 140130084312960 model_lib_v2.py:708] {'Loss/classification_loss': 0.44066486,
#  'Loss/localization_loss': 0.5322793,
#  'Loss/regularization_loss': 0.15339395,
#  'Loss/total_loss': 1.1263381,
#  'learning_rate': 0.0319994}
# INFO:tensorflow:Step 200 per-step time 0.554s
# I1106 03:02:05.170542 140130084312960 model_lib_v2.py:707] Step 200 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.3219596,
#  'Loss/localization_loss': 0.28077996,
#  'Loss/regularization_loss': 0.15316229,
#  'Loss/total_loss': 0.7559019,
#  'learning_rate': 0.0373328}
# I1106 03:02:05.170935 140130084312960 model_lib_v2.py:708] {'Loss/classification_loss': 0.3219596,
#  'Loss/localization_loss': 0.28077996,
#  'Loss/regularization_loss': 0.15316229,
#  'Loss/total_loss': 0.7559019,
#  'learning_rate': 0.0373328}
# INFO:tensorflow:Step 300 per-step time 0.567s
# I1106 03:03:01.886485 140130084312960 model_lib_v2.py:707] Step 300 per-step time 0.567s
# INFO:tensorflow:{'Loss/classification_loss': 0.25613225,
#  'Loss/localization_loss': 0.18456836,
#  'Loss/regularization_loss': 0.15285139,
#  'Loss/total_loss': 0.593552,
#  'learning_rate': 0.0426662}
# I1106 03:03:01.893599 140130084312960 model_lib_v2.py:708] {'Loss/classification_loss': 0.25613225,
#  'Loss/localization_loss': 0.18456836,
#  'Loss/regularization_loss': 0.15285139,
#  'Loss/total_loss': 0.593552,
#  'learning_rate': 0.0426662}
# INFO:tensorflow:Step 400 per-step time 0.618s
# I1106 03:04:03.728260 140130084312960 model_lib_v2.py:707] Step 400 per-step time 0.618s
# INFO:tensorflow:{'Loss/classification_loss': 0.17317772,
#  'Loss/localization_loss': 0.092406884,
#  'Loss/regularization_loss': 0.15248773,
#  'Loss/total_loss': 0.4180723,
#  'learning_rate': 0.047999598}
# I1106 03:04:03.728630 140130084312960 model_lib_v2.py:708] {'Loss/classification_loss': 0.17317772,
#  'Loss/localization_loss': 0.092406884,
#  'Loss/regularization_loss': 0.15248773,
#  'Loss/total_loss': 0.4180723,
#  'learning_rate': 0.047999598}
# INFO:tensorflow:Step 500 per-step time 0.576s
# I1106 03:05:01.317662 140130084312960 model_lib_v2.py:707] Step 500 per-step time 0.576s
# INFO:tensorflow:{'Loss/classification_loss': 0.17562805,
#  'Loss/localization_loss': 0.11022861,
#  'Loss/regularization_loss': 0.15210499,
#  'Loss/total_loss': 0.43796164,
#  'learning_rate': 0.053333}
# I1106 03:05:01.318035 140130084312960 model_lib_v2.py:708] {'Loss/classification_loss': 0.17562805,
#  'Loss/localization_loss': 0.11022861,
#  'Loss/regularization_loss': 0.15210499,
#  'Loss/total_loss': 0.43796164,
#  'learning_rate': 0.053333}
# INFO:tensorflow:Step 600 per-step time 0.573s
# I1106 03:05:58.608232 140130084312960 model_lib_v2.py:707] Step 600 per-step time 0.573s
# INFO:tensorflow:{'Loss/classification_loss': 0.17561735,
#  'Loss/localization_loss': 0.13540979,
#  'Loss/regularization_loss': 0.15169953,
#  'Loss/total_loss': 0.46272665,
#  'learning_rate': 0.0586664}
# I1106 03:05:58.608661 140130084312960 model_lib_v2.py:708] {'Loss/classification_loss': 0.17561735,
#  'Loss/localization_loss': 0.13540979,
#  'Loss/regularization_loss': 0.15169953,
#  'Loss/total_loss': 0.46272665,
#  'learning_rate': 0.0586664}
# INFO:tensorflow:Step 700 per-step time 0.589s
# I1106 03:06:57.523051 140130084312960 model_lib_v2.py:707] Step 700 per-step time 0.589s
# INFO:tensorflow:{'Loss/classification_loss': 0.14757767,
#  'Loss/localization_loss': 0.113383606,
#  'Loss/regularization_loss': 0.15124333,
#  'Loss/total_loss': 0.41220462,
#  'learning_rate': 0.0639998}
# I1106 03:06:57.523595 140130084312960 model_lib_v2.py:708] {'Loss/classification_loss': 0.14757767,
#  'Loss/localization_loss': 0.113383606,
#  'Loss/regularization_loss': 0.15124333,
#  'Loss/total_loss': 0.41220462,
#  'learning_rate': 0.0639998}
# INFO:tensorflow:Step 800 per-step time 0.586s
# I1106 03:07:56.069934 140130084312960 model_lib_v2.py:707] Step 800 per-step time 0.586s
# INFO:tensorflow:{'Loss/classification_loss': 0.13263024,
#  'Loss/localization_loss': 0.10626192,
#  'Loss/regularization_loss': 0.15075105,
#  'Loss/total_loss': 0.38964322,
#  'learning_rate': 0.069333196}
# I1106 03:07:56.070312 140130084312960 model_lib_v2.py:708] {'Loss/classification_loss': 0.13263024,
#  'Loss/localization_loss': 0.10626192,
#  'Loss/regularization_loss': 0.15075105,
#  'Loss/total_loss': 0.38964322,
#  'learning_rate': 0.069333196}
# INFO:tensorflow:Step 900 per-step time 0.560s
# I1106 03:08:52.073540 140130084312960 model_lib_v2.py:707] Step 900 per-step time 0.560s
# INFO:tensorflow:{'Loss/classification_loss': 0.13874449,
#  'Loss/localization_loss': 0.0712598,
#  'Loss/regularization_loss': 0.15029533,
#  'Loss/total_loss': 0.36029962,
#  'learning_rate': 0.074666604}
# I1106 03:08:52.073989 140130084312960 model_lib_v2.py:708] {'Loss/classification_loss': 0.13874449,
#  'Loss/localization_loss': 0.0712598,
#  'Loss/regularization_loss': 0.15029533,
#  'Loss/total_loss': 0.36029962,
#  'learning_rate': 0.074666604}
# INFO:tensorflow:Step 1000 per-step time 0.598s
# I1106 03:09:51.850385 140130084312960 model_lib_v2.py:707] Step 1000 per-step time 0.598s
# INFO:tensorflow:{'Loss/classification_loss': 0.15910742,
#  'Loss/localization_loss': 0.0800858,
#  'Loss/regularization_loss': 0.14977759,
#  'Loss/total_loss': 0.3889708,
#  'learning_rate': 0.08}
# I1106 03:09:51.850744 140130084312960 model_lib_v2.py:708] {'Loss/classification_loss': 0.15910742,
#  'Loss/localization_loss': 0.0800858,
#  'Loss/regularization_loss': 0.14977759,
#  'Loss/total_loss': 0.3889708,
#  'learning_rate': 0.08}
# INFO:tensorflow:Step 1100 per-step time 0.576s
# I1106 03:10:49.462814 140130084312960 model_lib_v2.py:707] Step 1100 per-step time 0.576s
# INFO:tensorflow:{'Loss/classification_loss': 0.12200415,
#  'Loss/localization_loss': 0.07456393,
#  'Loss/regularization_loss': 0.14919175,
#  'Loss/total_loss': 0.3457598,
#  'learning_rate': 0.07999918}
# I1106 03:10:49.463245 140130084312960 model_lib_v2.py:708] {'Loss/classification_loss': 0.12200415,
#  'Loss/localization_loss': 0.07456393,
#  'Loss/regularization_loss': 0.14919175,
#  'Loss/total_loss': 0.3457598,
#  'learning_rate': 0.07999918}
# INFO:tensorflow:Step 1200 per-step time 0.589s
# I1106 03:11:48.389193 140130084312960 model_lib_v2.py:707] Step 1200 per-step time 0.589s
# INFO:tensorflow:{'Loss/classification_loss': 0.11551578,
#  'Loss/localization_loss': 0.09457802,
#  'Loss/regularization_loss': 0.14858396,
#  'Loss/total_loss': 0.35867774,
#  'learning_rate': 0.079996705}
# I1106 03:11:48.389576 140130084312960 model_lib_v2.py:708] {'Loss/classification_loss': 0.11551578,
#  'Loss/localization_loss': 0.09457802,
#  'Loss/regularization_loss': 0.14858396,
#  'Loss/total_loss': 0.35867774,
#  'learning_rate': 0.079996705}
# INFO:tensorflow:Step 1300 per-step time 0.575s
# I1106 03:12:45.849506 140130084312960 model_lib_v2.py:707] Step 1300 per-step time 0.575s
# INFO:tensorflow:{'Loss/classification_loss': 0.12598869,
#  'Loss/localization_loss': 0.07587046,
#  'Loss/regularization_loss': 0.14800325,
#  'Loss/total_loss': 0.3498624,
#  'learning_rate': 0.0799926}
# I1106 03:12:45.856583 140130084312960 model_lib_v2.py:708] {'Loss/classification_loss': 0.12598869,
#  'Loss/localization_loss': 0.07587046,
#  'Loss/regularization_loss': 0.14800325,
#  'Loss/total_loss': 0.3498624,
#  'learning_rate': 0.0799926}
# INFO:tensorflow:Step 1400 per-step time 0.583s
# I1106 03:13:44.185681 140130084312960 model_lib_v2.py:707] Step 1400 per-step time 0.583s
# INFO:tensorflow:{'Loss/classification_loss': 0.14885594,
#  'Loss/localization_loss': 0.082268976,
#  'Loss/regularization_loss': 0.14739363,
#  'Loss/total_loss': 0.37851852,
#  'learning_rate': 0.07998685}
# I1106 03:13:44.186204 140130084312960 model_lib_v2.py:708] {'Loss/classification_loss': 0.14885594,
#  'Loss/localization_loss': 0.082268976,
#  'Loss/regularization_loss': 0.14739363,
#  'Loss/total_loss': 0.37851852,
#  'learning_rate': 0.07998685}
# INFO:tensorflow:Step 1500 per-step time 0.572s
# I1106 03:14:41.374197 140130084312960 model_lib_v2.py:707] Step 1500 per-step time 0.572s
# INFO:tensorflow:{'Loss/classification_loss': 0.14644109,
#  'Loss/localization_loss': 0.07221191,
#  'Loss/regularization_loss': 0.14684105,
#  'Loss/total_loss': 0.36549404,
#  'learning_rate': 0.07997945}
# I1106 03:14:41.374590 140130084312960 model_lib_v2.py:708] {'Loss/classification_loss': 0.14644109,
#  'Loss/localization_loss': 0.07221191,
#  'Loss/regularization_loss': 0.14684105,
#  'Loss/total_loss': 0.36549404,
#  'learning_rate': 0.07997945}
# INFO:tensorflow:Step 1600 per-step time 0.577s
# I1106 03:15:39.106795 140130084312960 model_lib_v2.py:707] Step 1600 per-step time 0.577s
# INFO:tensorflow:{'Loss/classification_loss': 0.1542377,
#  'Loss/localization_loss': 0.07341089,
#  'Loss/regularization_loss': 0.14615387,
#  'Loss/total_loss': 0.37380245,
#  'learning_rate': 0.079970405}
# I1106 03:15:39.107182 140130084312960 model_lib_v2.py:708] {'Loss/classification_loss': 0.1542377,
#  'Loss/localization_loss': 0.07341089,
#  'Loss/regularization_loss': 0.14615387,
#  'Loss/total_loss': 0.37380245,
#  'learning_rate': 0.079970405}
# INFO:tensorflow:Step 1700 per-step time 0.567s
# I1106 03:16:35.787754 140130084312960 model_lib_v2.py:707] Step 1700 per-step time 0.567s
# INFO:tensorflow:{'Loss/classification_loss': 0.11777836,
#  'Loss/localization_loss': 0.08643412,
#  'Loss/regularization_loss': 0.14562409,
#  'Loss/total_loss': 0.3498366,
#  'learning_rate': 0.07995972}
# I1106 03:16:35.788136 140130084312960 model_lib_v2.py:708] {'Loss/classification_loss': 0.11777836,
#  'Loss/localization_loss': 0.08643412,
#  'Loss/regularization_loss': 0.14562409,
#  'Loss/total_loss': 0.3498366,
#  'learning_rate': 0.07995972}
# INFO:tensorflow:Step 1800 per-step time 0.592s
# I1106 03:17:35.009780 140130084312960 model_lib_v2.py:707] Step 1800 per-step time 0.592s
# INFO:tensorflow:{'Loss/classification_loss': 0.092184514,
#  'Loss/localization_loss': 0.06342698,
#  'Loss/regularization_loss': 0.14496022,
#  'Loss/total_loss': 0.3005717,
#  'learning_rate': 0.0799474}
# I1106 03:17:35.010226 140130084312960 model_lib_v2.py:708] {'Loss/classification_loss': 0.092184514,
#  'Loss/localization_loss': 0.06342698,
#  'Loss/regularization_loss': 0.14496022,
#  'Loss/total_loss': 0.3005717,
#  'learning_rate': 0.0799474}
# INFO:tensorflow:Step 1900 per-step time 0.564s
# I1106 03:18:31.367844 140130084312960 model_lib_v2.py:707] Step 1900 per-step time 0.564s
# INFO:tensorflow:{'Loss/classification_loss': 0.091291524,
#  'Loss/localization_loss': 0.06730278,
#  'Loss/regularization_loss': 0.14435582,
#  'Loss/total_loss': 0.30295014,
#  'learning_rate': 0.07993342}
# I1106 03:18:31.368426 140130084312960 model_lib_v2.py:708] {'Loss/classification_loss': 0.091291524,
#  'Loss/localization_loss': 0.06730278,
#  'Loss/regularization_loss': 0.14435582,
#  'Loss/total_loss': 0.30295014,
#  'learning_rate': 0.07993342}
# INFO:tensorflow:Step 2000 per-step time 0.585s
# I1106 03:19:29.859818 140130084312960 model_lib_v2.py:707] Step 2000 per-step time 0.585s
# INFO:tensorflow:{'Loss/classification_loss': 0.10569775,
#  'Loss/localization_loss': 0.07073578,
#  'Loss/regularization_loss': 0.14375441,
#  'Loss/total_loss': 0.32018793,
#  'learning_rate': 0.07991781}
# I1106 03:19:29.860160 140130084312960 model_lib_v2.py:708] {'Loss/classification_loss': 0.10569775,
#  'Loss/localization_loss': 0.07073578,
#  'Loss/regularization_loss': 0.14375441,
#  'Loss/total_loss': 0.32018793,
#  'learning_rate': 0.07991781}

# %%
# !tensorboard --logdir=/content/Tensorflow/workspace/models/erd_detection/train/events.out.tfevents.1667703541.323bb93b51d2.803.0.v2
# Out:
# 2022-11-06 03:27:26.293756: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-11-06 03:27:26.947562: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-11-06 03:27:26.947730: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-11-06 03:27:26.947750: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# [2022-11-06T03:27:29Z ERROR rustboard_core::disk_logdir] Log directory /content/Tensorflow/workspace/models/erd_detection/train/events.out.tfevents.1667703541.323bb93b51d2.803.0.v2 is not a prefix of run directory /content/Tensorflow/workspace/models/erd_detection/train
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.10.1 at http://localhost:6006/ (Press CTRL+C to quit)
# [2022-11-06T03:27:34Z ERROR rustboard_core::disk_logdir] Log directory /content/Tensorflow/workspace/models/erd_detection/train/events.out.tfevents.1667703541.323bb93b51d2.803.0.v2 is not a prefix of run directory /content/Tensorflow/workspace/models/erd_detection/train
# [2022-11-06T03:27:39Z ERROR rustboard_core::disk_logdir] Log directory /content/Tensorflow/workspace/models/erd_detection/train/events.out.tfevents.1667703541.323bb93b51d2.803.0.v2 is not a prefix of run directory /content/Tensorflow/workspace/models/erd_detection/train
# [2022-11-06T03:27:44Z ERROR rustboard_core::disk_logdir] Log directory /content/Tensorflow/workspace/models/erd_detection/train/events.out.tfevents.1667703541.323bb93b51d2.803.0.v2 is not a prefix of run directory /content/Tensorflow/workspace/models/erd_detection/train
# [2022-11-06T03:27:49Z ERROR rustboard_core::disk_logdir] Log directory /content/Tensorflow/workspace/models/erd_detection/train/events.out.tfevents.1667703541.323bb93b51d2.803.0.v2 is not a prefix of run directory /content/Tensorflow/workspace/models/erd_detection/train
# ^C

# %%
import os
import tensorflow as tf
tf.config.run_functions_eagerly(True)
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder
from object_detection.utils import config_util

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(paths['CHECKPOINT_PATH'], 'ckpt-3')).expect_partial()

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
category_index = label_map_util.create_category_index_from_labelmap(files['LABELMAP'])

# %%
IMAGE_PATH = '/content/Tensorflow/workspace/images/test/120.png'

# %%
IMAGE_PATH
# Out:
# '/content/Tensorflow/workspace/images/test/120.png'

# %%
img = cv2.imread(IMAGE_PATH)
print(img.size)
image_np = np.array(img)


input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)


num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

print(image_np_with_detections)


viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=5,
            min_score_thresh=.8,
            agnostic_mode=False)
boxes = detections['detection_boxes'][0]
print(boxes)

#print(image_np_with_detections)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
#plt.show()
# Out:
# 21083328
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]
# [0.00064991 0.15890327 0.41518962 0.38606218]

# %%
boxes = np.squeeze(detections['detection_boxes'])
classes = np.squeeze(detections['detection_classes'])

scores = np.squeeze(detections['detection_scores'])
#set a min thresh score, say 0.8
min_score_thresh = 0.8
bboxes = boxes[scores > min_score_thresh]

#get image size
im_width, im_height = (12415776,12415776)
final_box = []
print(classes)
for box in bboxes:
    ymin, xmin, ymax, xmax = box
    print(xmin * im_width, xmax * im_width, ymin * im_height, ymax * im_height)
# Out:
# [4 4 4 0 4 4 4 4 2 4 2 0 0 5 5 0 4 0 5 0 5 4 0 0 5 5 2 4 5 0 5 2 1 0 5 0 5
#  5 0 5 5 1 4 2 2 5 4 2 0 0 0 6 6 4 5 4 1 4 5 6 5 4 4 5 6 6 0 2 1 5 4 5 5 4
#  4 6 1 2 4 5 0 4 1 5 5 5 5 1 4 2 5 5 1 3 4 0 1 5 2 2]
# 3424595.3995485306 4543422.466052055 10433319.502819061 12415776.0
# 7813697.758541107 8954063.628650665 37128.349883794785 2067621.5408706665
# 4231522.014884949 5245488.668546677 183505.99998736382 2024700.821697235
# 56829.36182498932 2505540.0889577866 3519262.5301065445 7259261.350307465
# 2575733.2405171394 3681456.6406145096 88062.93967223167 2027793.0701379776
# 9032243.454431534 10161218.660905838 170134.34735012054 1994761.8476829529
# 4160996.4012908936 5324145.078746796 8087271.275911331 10140206.024259567
# 2524606.610888958 3698133.395098686 7912705.951526642 10184302.663684845
# 8484798.184410095 9580045.422729492 3945541.761817932 7103235.4558467865

# %%
 # !zip -r module_1.zip Tensorflow/
# Out:
#   adding: Tensorflow// (stored 0%)
#   adding: Tensorflow//models/ (stored 0%)
#   adding: Tensorflow//models/docs/ (stored 0%)
#   adding: Tensorflow//models/docs/vision/ (stored 0%)
#   adding: Tensorflow//models/docs/vision/image_classification.ipynb (deflated 76%)
#   adding: Tensorflow//models/docs/index.md (deflated 64%)
#   adding: Tensorflow//models/docs/README.md (deflated 51%)
#   adding: Tensorflow//models/docs/orbit/ (stored 0%)
#   adding: Tensorflow//models/docs/orbit/index.ipynb (deflated 76%)
#   adding: Tensorflow//models/docs/nlp/ (stored 0%)
#   adding: Tensorflow//models/docs/nlp/decoding_api.ipynb (deflated 76%)
#   adding: Tensorflow//models/docs/nlp/customize_encoder.ipynb (deflated 79%)
#   adding: Tensorflow//models/docs/nlp/fine_tune_bert.ipynb (deflated 78%)
#   adding: Tensorflow//models/docs/nlp/_guide_toc.yaml (deflated 31%)
#   adding: Tensorflow//models/docs/nlp/index.ipynb (deflated 79%)
#   adding: Tensorflow//models/CODEOWNERS (deflated 56%)
#   adding: Tensorflow//models/tensorflow_models/ (stored 0%)
#   adding: Tensorflow//models/tensorflow_models/vision/ (stored 0%)
#   adding: Tensorflow//models/tensorflow_models/vision/__init__.py (deflated 45%)
#   adding: Tensorflow//models/tensorflow_models/tensorflow_models_pypi.ipynb (deflated 76%)
#   adding: Tensorflow//models/tensorflow_models/tensorflow_models_test.py (deflated 46%)
#   adding: Tensorflow//models/tensorflow_models/__init__.py (deflated 45%)
#   adding: Tensorflow//models/tensorflow_models/nlp/ (stored 0%)
#   adding: Tensorflow//models/tensorflow_models/nlp/__init__.py (deflated 43%)
#   adding: Tensorflow//models/official/ (stored 0%)
#   adding: Tensorflow//models/official/vision/ (stored 0%)
#   adding: Tensorflow//models/official/vision/ops/ (stored 0%)
#   adding: Tensorflow//models/official/vision/ops/target_gather.py (deflated 67%)
#   adding: Tensorflow//models/official/vision/ops/preprocess_ops.py (deflated 79%)
#   adding: Tensorflow//models/official/vision/ops/iou_similarity_test.py (deflated 62%)
#   adding: Tensorflow//models/official/vision/ops/augment_test.py (deflated 83%)
#   adding: Tensorflow//models/official/vision/ops/target_gather_test.py (deflated 67%)
#   adding: Tensorflow//models/official/vision/ops/sampling_ops.py (deflated 72%)
#   adding: Tensorflow//models/official/vision/ops/mask_ops_test.py (deflated 56%)
#   adding: Tensorflow//models/official/vision/ops/nms.py (deflated 68%)
#   adding: Tensorflow//models/official/vision/ops/preprocess_ops_3d_test.py (deflated 73%)
#   adding: Tensorflow//models/official/vision/ops/preprocess_ops_test.py (deflated 78%)
#   adding: Tensorflow//models/official/vision/ops/box_ops.py (deflated 79%)
#   adding: Tensorflow//models/official/vision/ops/augment.py (deflated 79%)
#   adding: Tensorflow//models/official/vision/ops/box_matcher.py (deflated 72%)
#   adding: Tensorflow//models/official/vision/ops/preprocess_ops_3d.py (deflated 72%)
#   adding: Tensorflow//models/official/vision/ops/anchor_generator_test.py (deflated 77%)
#   adding: Tensorflow//models/official/vision/ops/anchor_generator.py (deflated 71%)
#   adding: Tensorflow//models/official/vision/ops/anchor_test.py (deflated 72%)
#   adding: Tensorflow//models/official/vision/ops/iou_similarity.py (deflated 69%)
#   adding: Tensorflow//models/official/vision/ops/anchor.py (deflated 77%)
#   adding: Tensorflow//models/official/vision/ops/mask_ops.py (deflated 67%)
#   adding: Tensorflow//models/official/vision/ops/__init__.py (deflated 37%)
#   adding: Tensorflow//models/official/vision/ops/spatial_transform_ops.py (deflated 77%)
#   adding: Tensorflow//models/official/vision/ops/box_matcher_test.py (deflated 66%)
#   adding: Tensorflow//models/official/vision/train_spatial_partitioning.py (deflated 66%)
#   adding: Tensorflow//models/official/vision/evaluation/ (stored 0%)
#   adding: Tensorflow//models/official/vision/evaluation/panoptic_quality.py (deflated 70%)
#   adding: Tensorflow//models/official/vision/evaluation/iou_test.py (deflated 75%)
#   adding: Tensorflow//models/official/vision/evaluation/coco_utils_test.py (deflated 51%)
#   adding: Tensorflow//models/official/vision/evaluation/iou.py (deflated 66%)
#   adding: Tensorflow//models/official/vision/evaluation/segmentation_metrics.py (deflated 74%)
#   adding: Tensorflow//models/official/vision/evaluation/coco_utils.py (deflated 73%)
#   adding: Tensorflow//models/official/vision/evaluation/panoptic_quality_evaluator.py (deflated 68%)
#   adding: Tensorflow//models/official/vision/evaluation/wod_detection_evaluator.py (deflated 69%)
#   adding: Tensorflow//models/official/vision/evaluation/coco_evaluator.py (deflated 74%)
#   adding: Tensorflow//models/official/vision/evaluation/segmentation_metrics_test.py (deflated 67%)
#   adding: Tensorflow//models/official/vision/evaluation/__init__.py (deflated 37%)
#   adding: Tensorflow//models/official/vision/evaluation/panoptic_quality_test.py (deflated 86%)
#   adding: Tensorflow//models/official/vision/evaluation/panoptic_quality_evaluator_test.py (deflated 68%)
#   adding: Tensorflow//models/official/vision/MODEL_GARDEN.md (deflated 79%)
#   adding: Tensorflow//models/official/vision/utils/ (stored 0%)
#   adding: Tensorflow//models/official/vision/utils/object_detection/ (stored 0%)
#   adding: Tensorflow//models/official/vision/utils/object_detection/shape_utils.py (deflated 62%)
#   adding: Tensorflow//models/official/vision/utils/object_detection/ops.py (deflated 57%)
#   adding: Tensorflow//models/official/vision/utils/object_detection/box_list_ops.py (deflated 77%)
#   adding: Tensorflow//models/official/vision/utils/object_detection/target_assigner.py (deflated 83%)
#   adding: Tensorflow//models/official/vision/utils/object_detection/box_coder.py (deflated 64%)
#   adding: Tensorflow//models/official/vision/utils/object_detection/box_list.py (deflated 66%)
#   adding: Tensorflow//models/official/vision/utils/object_detection/visualization_utils.py (deflated 75%)
#   adding: Tensorflow//models/official/vision/utils/object_detection/matcher.py (deflated 71%)
#   adding: Tensorflow//models/official/vision/utils/object_detection/faster_rcnn_box_coder.py (deflated 61%)
#   adding: Tensorflow//models/official/vision/utils/object_detection/minibatch_sampler.py (deflated 57%)
#   adding: Tensorflow//models/official/vision/utils/object_detection/region_similarity_calculator.py (deflated 67%)
#   adding: Tensorflow//models/official/vision/utils/object_detection/__init__.py (deflated 37%)
#   adding: Tensorflow//models/official/vision/utils/object_detection/balanced_positive_negative_sampler.py (deflated 73%)
#   adding: Tensorflow//models/official/vision/utils/object_detection/argmax_matcher.py (deflated 71%)
#   adding: Tensorflow//models/official/vision/utils/object_detection/preprocessor.py (deflated 75%)
#   adding: Tensorflow//models/official/vision/utils/__init__.py (deflated 37%)
#   adding: Tensorflow//models/official/vision/train.py (deflated 56%)
#   adding: Tensorflow//models/official/vision/configs/ (stored 0%)
#   adding: Tensorflow//models/official/vision/configs/maskrcnn_test.py (deflated 53%)
#   adding: Tensorflow//models/official/vision/configs/experiments/ (stored 0%)
#   adding: Tensorflow//models/official/vision/configs/experiments/image_classification/ (stored 0%)
#   adding: Tensorflow//models/official/vision/configs/experiments/image_classification/imagenet_mobilenetv2_gpu.yaml (deflated 56%)
#   adding: Tensorflow//models/official/vision/configs/experiments/image_classification/imagenet_resnet50_tfds_tpu.yaml (deflated 58%)
#   adding: Tensorflow//models/official/vision/configs/experiments/image_classification/imagenet_resnetrs270_i256.yaml (deflated 58%)
#   adding: Tensorflow//models/official/vision/configs/experiments/image_classification/imagenet_resnetrs420_i320.yaml (deflated 59%)
#   adding: Tensorflow//models/official/vision/configs/experiments/image_classification/imagenet_resnetrs50_i160.yaml (deflated 58%)
#   adding: Tensorflow//models/official/vision/configs/experiments/image_classification/imagenet_resnetrs101_i160.yaml (deflated 58%)
#   adding: Tensorflow//models/official/vision/configs/experiments/image_classification/imagenet_resnetrs152_i192.yaml (deflated 58%)
#   adding: Tensorflow//models/official/vision/configs/experiments/image_classification/imagenet_resnet50_gpu.yaml (deflated 55%)
#   adding: Tensorflow//models/official/vision/configs/experiments/image_classification/imagenet_mobilenetv1_tpu.yaml (deflated 55%)
#   adding: Tensorflow//models/official/vision/configs/experiments/image_classification/imagenet_mobilenetv2_tpu.yaml (deflated 55%)
#   adding: Tensorflow//models/official/vision/configs/experiments/image_classification/imagenet_resnetrs101_i192.yaml (deflated 58%)
#   adding: Tensorflow//models/official/vision/configs/experiments/image_classification/imagenet_mobilenetv3small_tpu.yaml (deflated 57%)
#   adding: Tensorflow//models/official/vision/configs/experiments/image_classification/imagenet_resnetrs350_i320.yaml (deflated 58%)
#   adding: Tensorflow//models/official/vision/configs/experiments/image_classification/imagenet_resnet101_tpu.yaml (deflated 57%)
#   adding: Tensorflow//models/official/vision/configs/experiments/image_classification/imagenet_resnetrs152_i256.yaml (deflated 58%)
#   adding: Tensorflow//models/official/vision/configs/experiments/image_classification/imagenet_resnetrs152_i224.yaml (deflated 58%)
#   adding: Tensorflow//models/official/vision/configs/experiments/image_classification/imagenet_resnet50_deeplab_tpu.yaml (deflated 58%)
#   adding: Tensorflow//models/official/vision/configs/experiments/image_classification/imagenet_resnet101_deeplab_tpu.yaml (deflated 57%)
#   adding: Tensorflow//models/official/vision/configs/experiments/image_classification/imagenet_resnet50_tpu.yaml (deflated 57%)
#   adding: Tensorflow//models/official/vision/configs/experiments/image_classification/imagenet_mobilenetv3.5_avgseg_tpu.yaml (deflated 56%)
#   adding: Tensorflow//models/official/vision/configs/experiments/image_classification/imagenet_resnet152_tpu.yaml (deflated 56%)
#   adding: Tensorflow//models/official/vision/configs/experiments/image_classification/imagenet_mobilenetv3.5_avg_tpu.yaml (deflated 56%)
#   adding: Tensorflow//models/official/vision/configs/experiments/image_classification/imagenet_mobilenetv3large_tpu.yaml (deflated 57%)
#   adding: Tensorflow//models/official/vision/configs/experiments/image_classification/imagenet_resnetrs350_i256.yaml (deflated 58%)
#   adding: Tensorflow//models/official/vision/configs/experiments/image_classification/imagenet_resnetrs200_i256.yaml (deflated 58%)
#   adding: Tensorflow//models/official/vision/configs/experiments/retinanet/ (stored 0%)
#   adding: Tensorflow//models/official/vision/configs/experiments/retinanet/resnet50fpn_coco_tpu4x4_benchmark.yaml (deflated 31%)
#   adding: Tensorflow//models/official/vision/configs/experiments/retinanet/coco_mobiledetcpu_tpu.yaml (deflated 55%)
#   adding: Tensorflow//models/official/vision/configs/experiments/retinanet/coco_spinenet49_mobile_tpu.yaml (deflated 55%)
#   adding: Tensorflow//models/official/vision/configs/experiments/retinanet/coco_mobilenetv2_tpu.yaml (deflated 56%)
#   adding: Tensorflow//models/official/vision/configs/experiments/retinanet/coco_spinenet96_tpu.yaml (deflated 53%)
#   adding: Tensorflow//models/official/vision/configs/experiments/retinanet/coco_spinenet49s_mobile_tpu.yaml (deflated 55%)
#   adding: Tensorflow//models/official/vision/configs/experiments/retinanet/coco_spinenet190_tpu.yaml (deflated 55%)
#   adding: Tensorflow//models/official/vision/configs/experiments/retinanet/coco_spinenet143_tpu.yaml (deflated 53%)
#   adding: Tensorflow//models/official/vision/configs/experiments/retinanet/coco_spinenet49xs_mobile_tpu.yaml (deflated 54%)
#   adding: Tensorflow//models/official/vision/configs/experiments/retinanet/coco_spinenet49_tpu.yaml (deflated 53%)
#   adding: Tensorflow//models/official/vision/configs/experiments/retinanet/resnet50fpn_coco_tfds_tpu.yaml (deflated 54%)
#   adding: Tensorflow//models/official/vision/configs/experiments/video_classification/ (stored 0%)
#   adding: Tensorflow//models/official/vision/configs/experiments/video_classification/k600_slowonly8x8_tpu.yaml (deflated 69%)
#   adding: Tensorflow//models/official/vision/configs/experiments/video_classification/k400_slowonly8x8_tpu.yaml (deflated 69%)
#   adding: Tensorflow//models/official/vision/configs/experiments/video_classification/k400_slowonly16x4_tpu.yaml (deflated 69%)
#   adding: Tensorflow//models/official/vision/configs/experiments/video_classification/k600_3d-resnet50_tpu.yaml (deflated 69%)
#   adding: Tensorflow//models/official/vision/configs/experiments/video_classification/k400_3d-resnet50_tpu.yaml (deflated 69%)
#   adding: Tensorflow//models/official/vision/configs/experiments/video_classification/k400_resnet3drs_50_tpu.yaml (deflated 63%)
#   adding: Tensorflow//models/official/vision/configs/experiments/video_classification/k600_3d-resnet50g_tpu.yaml (deflated 68%)
#   adding: Tensorflow//models/official/vision/configs/experiments/maskrcnn/ (stored 0%)
#   adding: Tensorflow//models/official/vision/configs/experiments/maskrcnn/coco_mobilenetv2_mrcnn_tpu.yaml (deflated 37%)
#   adding: Tensorflow//models/official/vision/configs/experiments/maskrcnn/coco_spinenet143_cascadercnn_tpu.yaml (deflated 51%)
#   adding: Tensorflow//models/official/vision/configs/experiments/maskrcnn/coco_spinenet49_mrcnn_tpu.yaml (deflated 49%)
#   adding: Tensorflow//models/official/vision/configs/experiments/maskrcnn/coco_spinenet49_cascadercnn_tpu.yaml (deflated 52%)
#   adding: Tensorflow//models/official/vision/configs/experiments/maskrcnn/coco_spinenet143_mrcnn_tpu.yaml (deflated 49%)
#   adding: Tensorflow//models/official/vision/configs/experiments/maskrcnn/r50fpn_640_coco_scratch_tpu4x4.yaml (deflated 47%)
#   adding: Tensorflow//models/official/vision/configs/experiments/maskrcnn/coco_spinenet96_cascadercnn_tpu.yaml (deflated 51%)
#   adding: Tensorflow//models/official/vision/configs/experiments/maskrcnn/coco_spinenet96_mrcnn_tpu.yaml (deflated 49%)
#   adding: Tensorflow//models/official/vision/configs/experiments/semantic_segmentation/ (stored 0%)
#   adding: Tensorflow//models/official/vision/configs/experiments/semantic_segmentation/deeplabv3plus_resnet101_cityscapes_tfds_tpu.yaml (deflated 58%)
#   adding: Tensorflow//models/official/vision/configs/image_classification_test.py (deflated 56%)
#   adding: Tensorflow//models/official/vision/configs/retinanet_test.py (deflated 53%)
#   adding: Tensorflow//models/official/vision/configs/semantic_segmentation_test.py (deflated 54%)
#   adding: Tensorflow//models/official/vision/configs/video_classification_test.py (deflated 55%)
#   adding: Tensorflow//models/official/vision/configs/common.py (deflated 64%)
#   adding: Tensorflow//models/official/vision/configs/image_classification.py (deflated 85%)
#   adding: Tensorflow//models/official/vision/configs/backbones.py (deflated 67%)
#   adding: Tensorflow//models/official/vision/configs/video_classification.py (deflated 81%)
#   adding: Tensorflow//models/official/vision/configs/retinanet.py (deflated 79%)
#   adding: Tensorflow//models/official/vision/configs/maskrcnn.py (deflated 83%)
#   adding: Tensorflow//models/official/vision/configs/backbones_3d.py (deflated 73%)
#   adding: Tensorflow//models/official/vision/configs/__init__.py (deflated 53%)
#   adding: Tensorflow//models/official/vision/configs/semantic_segmentation.py (deflated 86%)
#   adding: Tensorflow//models/official/vision/configs/decoders.py (deflated 54%)
#   adding: Tensorflow//models/official/vision/registry_imports.py (deflated 39%)
#   adding: Tensorflow//models/official/vision/losses/ (stored 0%)
#   adding: Tensorflow//models/official/vision/losses/maskrcnn_losses.py (deflated 76%)
#   adding: Tensorflow//models/official/vision/losses/segmentation_losses_test.py (deflated 66%)
#   adding: Tensorflow//models/official/vision/losses/loss_utils.py (deflated 52%)
#   adding: Tensorflow//models/official/vision/losses/retinanet_losses.py (deflated 69%)
#   adding: Tensorflow//models/official/vision/losses/segmentation_losses.py (deflated 71%)
#   adding: Tensorflow//models/official/vision/losses/focal_loss.py (deflated 55%)
#   adding: Tensorflow//models/official/vision/losses/__init__.py (deflated 37%)
#   adding: Tensorflow//models/official/vision/modeling/ (stored 0%)
#   adding: Tensorflow//models/official/vision/modeling/factory_3d.py (deflated 63%)
#   adding: Tensorflow//models/official/vision/modeling/video_classification_model.py (deflated 65%)
#   adding: Tensorflow//models/official/vision/modeling/layers/ (stored 0%)
#   adding: Tensorflow//models/official/vision/modeling/layers/deeplab.py (deflated 73%)
#   adding: Tensorflow//models/official/vision/modeling/layers/detection_generator_test.py (deflated 79%)
#   adding: Tensorflow//models/official/vision/modeling/layers/roi_generator.py (deflated 77%)
#   adding: Tensorflow//models/official/vision/modeling/layers/roi_sampler.py (deflated 70%)
#   adding: Tensorflow//models/official/vision/modeling/layers/nn_blocks_3d.py (deflated 75%)
#   adding: Tensorflow//models/official/vision/modeling/layers/nn_blocks.py (deflated 86%)
#   adding: Tensorflow//models/official/vision/modeling/layers/mask_sampler.py (deflated 76%)
#   adding: Tensorflow//models/official/vision/modeling/layers/nn_layers_test.py (deflated 81%)
#   adding: Tensorflow//models/official/vision/modeling/layers/nn_layers.py (deflated 78%)
#   adding: Tensorflow//models/official/vision/modeling/layers/roi_aligner.py (deflated 53%)
#   adding: Tensorflow//models/official/vision/modeling/layers/nn_blocks_3d_test.py (deflated 56%)
#   adding: Tensorflow//models/official/vision/modeling/layers/detection_generator.py (deflated 82%)
#   adding: Tensorflow//models/official/vision/modeling/layers/deeplab_test.py (deflated 55%)
#   adding: Tensorflow//models/official/vision/modeling/layers/__init__.py (deflated 72%)
#   adding: Tensorflow//models/official/vision/modeling/layers/nn_blocks_test.py (deflated 86%)
#   adding: Tensorflow//models/official/vision/modeling/layers/roi_aligner_test.py (deflated 47%)
#   adding: Tensorflow//models/official/vision/modeling/layers/box_sampler.py (deflated 61%)
#   adding: Tensorflow//models/official/vision/modeling/decoders/ (stored 0%)
#   adding: Tensorflow//models/official/vision/modeling/decoders/aspp_test.py (deflated 56%)
#   adding: Tensorflow//models/official/vision/modeling/decoders/factory_test.py (deflated 75%)
#   adding: Tensorflow//models/official/vision/modeling/decoders/fpn.py (deflated 69%)
#   adding: Tensorflow//models/official/vision/modeling/decoders/aspp.py (deflated 68%)
#   adding: Tensorflow//models/official/vision/modeling/decoders/fpn_test.py (deflated 67%)
#   adding: Tensorflow//models/official/vision/modeling/decoders/nasfpn.py (deflated 70%)
#   adding: Tensorflow//models/official/vision/modeling/decoders/__init__.py (deflated 44%)
#   adding: Tensorflow//models/official/vision/modeling/decoders/factory.py (deflated 62%)
#   adding: Tensorflow//models/official/vision/modeling/decoders/nasfpn_test.py (deflated 51%)
#   adding: Tensorflow//models/official/vision/modeling/video_classification_model_test.py (deflated 62%)
#   adding: Tensorflow//models/official/vision/modeling/factory_test.py (deflated 75%)
#   adding: Tensorflow//models/official/vision/modeling/classification_model_test.py (deflated 74%)
#   adding: Tensorflow//models/official/vision/modeling/maskrcnn_model_test.py (deflated 80%)
#   adding: Tensorflow//models/official/vision/modeling/segmentation_model_test.py (deflated 60%)
#   adding: Tensorflow//models/official/vision/modeling/segmentation_model.py (deflated 59%)
#   adding: Tensorflow//models/official/vision/modeling/classification_model.py (deflated 64%)
#   adding: Tensorflow//models/official/vision/modeling/models/ (stored 0%)
#   adding: Tensorflow//models/official/vision/modeling/models/__init__.py (deflated 51%)
#   adding: Tensorflow//models/official/vision/modeling/retinanet_model.py (deflated 70%)
#   adding: Tensorflow//models/official/vision/modeling/retinanet_model_test.py (deflated 78%)
#   adding: Tensorflow//models/official/vision/modeling/maskrcnn_model.py (deflated 74%)
#   adding: Tensorflow//models/official/vision/modeling/backbones/ (stored 0%)
#   adding: Tensorflow//models/official/vision/modeling/backbones/mobiledet.py (deflated 81%)
#   adding: Tensorflow//models/official/vision/modeling/backbones/resnet_3d_test.py (deflated 63%)
#   adding: Tensorflow//models/official/vision/modeling/backbones/spinenet.py (deflated 75%)
#   adding: Tensorflow//models/official/vision/modeling/backbones/mobilenet_test.py (deflated 77%)
#   adding: Tensorflow//models/official/vision/modeling/backbones/resnet_deeplab.py (deflated 75%)
#   adding: Tensorflow//models/official/vision/modeling/backbones/resnet_3d.py (deflated 78%)
#   adding: Tensorflow//models/official/vision/modeling/backbones/resnet.py (deflated 75%)
#   adding: Tensorflow//models/official/vision/modeling/backbones/efficientnet.py (deflated 70%)
#   adding: Tensorflow//models/official/vision/modeling/backbones/vit_test.py (deflated 63%)
#   adding: Tensorflow//models/official/vision/modeling/backbones/resnet_test.py (deflated 67%)
#   adding: Tensorflow//models/official/vision/modeling/backbones/factory_test.py (deflated 81%)
#   adding: Tensorflow//models/official/vision/modeling/backbones/revnet.py (deflated 65%)
#   adding: Tensorflow//models/official/vision/modeling/backbones/vit_specs.py (deflated 68%)
#   adding: Tensorflow//models/official/vision/modeling/backbones/vit.py (deflated 72%)
#   adding: Tensorflow//models/official/vision/modeling/backbones/mobiledet_test.py (deflated 62%)
#   adding: Tensorflow//models/official/vision/modeling/backbones/resnet_deeplab_test.py (deflated 68%)
#   adding: Tensorflow//models/official/vision/modeling/backbones/spinenet_mobile.py (deflated 74%)
#   adding: Tensorflow//models/official/vision/modeling/backbones/__init__.py (deflated 59%)
#   adding: Tensorflow//models/official/vision/modeling/backbones/mobilenet.py (deflated 81%)
#   adding: Tensorflow//models/official/vision/modeling/backbones/revnet_test.py (deflated 60%)
#   adding: Tensorflow//models/official/vision/modeling/backbones/factory.py (deflated 60%)
#   adding: Tensorflow//models/official/vision/modeling/backbones/spinenet_test.py (deflated 63%)
#   adding: Tensorflow//models/official/vision/modeling/backbones/spinenet_mobile_test.py (deflated 64%)
#   adding: Tensorflow//models/official/vision/modeling/backbones/efficientnet_test.py (deflated 63%)
#   adding: Tensorflow//models/official/vision/modeling/heads/ (stored 0%)
#   adding: Tensorflow//models/official/vision/modeling/heads/instance_heads.py (deflated 82%)
#   adding: Tensorflow//models/official/vision/modeling/heads/dense_prediction_heads.py (deflated 83%)
#   adding: Tensorflow//models/official/vision/modeling/heads/segmentation_heads_test.py (deflated 68%)
#   adding: Tensorflow//models/official/vision/modeling/heads/segmentation_heads.py (deflated 76%)
#   adding: Tensorflow//models/official/vision/modeling/heads/instance_heads_test.py (deflated 73%)
#   adding: Tensorflow//models/official/vision/modeling/heads/dense_prediction_heads_test.py (deflated 75%)
#   adding: Tensorflow//models/official/vision/modeling/heads/__init__.py (deflated 51%)
#   adding: Tensorflow//models/official/vision/modeling/__init__.py (deflated 48%)
#   adding: Tensorflow//models/official/vision/modeling/factory.py (deflated 83%)
#   adding: Tensorflow//models/official/vision/dataloaders/ (stored 0%)
#   adding: Tensorflow//models/official/vision/dataloaders/utils_test.py (deflated 59%)
#   adding: Tensorflow//models/official/vision/dataloaders/maskrcnn_input.py (deflated 74%)
#   adding: Tensorflow//models/official/vision/dataloaders/tf_example_label_map_decoder_test.py (deflated 78%)
#   adding: Tensorflow//models/official/vision/dataloaders/input_reader_factory.py (deflated 53%)
#   adding: Tensorflow//models/official/vision/dataloaders/tf_example_label_map_decoder.py (deflated 56%)
#   adding: Tensorflow//models/official/vision/dataloaders/tf_example_decoder.py (deflated 73%)
#   adding: Tensorflow//models/official/vision/dataloaders/classification_input.py (deflated 73%)
#   adding: Tensorflow//models/official/vision/dataloaders/tf_example_decoder_test.py (deflated 85%)
#   adding: Tensorflow//models/official/vision/dataloaders/retinanet_input.py (deflated 75%)
#   adding: Tensorflow//models/official/vision/dataloaders/input_reader.py (deflated 71%)
#   adding: Tensorflow//models/official/vision/dataloaders/parser.py (deflated 60%)
#   adding: Tensorflow//models/official/vision/dataloaders/utils.py (deflated 59%)
#   adding: Tensorflow//models/official/vision/dataloaders/tfds_segmentation_decoders.py (deflated 58%)
#   adding: Tensorflow//models/official/vision/dataloaders/tfds_factory.py (deflated 70%)
#   adding: Tensorflow//models/official/vision/dataloaders/tfds_classification_decoders.py (deflated 48%)
#   adding: Tensorflow//models/official/vision/dataloaders/video_input_test.py (deflated 77%)
#   adding: Tensorflow//models/official/vision/dataloaders/tfexample_utils.py (deflated 77%)
#   adding: Tensorflow//models/official/vision/dataloaders/segmentation_input.py (deflated 72%)
#   adding: Tensorflow//models/official/vision/dataloaders/tfds_factory_test.py (deflated 72%)
#   adding: Tensorflow//models/official/vision/dataloaders/__init__.py (deflated 37%)
#   adding: Tensorflow//models/official/vision/dataloaders/tfds_detection_decoders.py (deflated 59%)
#   adding: Tensorflow//models/official/vision/dataloaders/decoder.py (deflated 44%)
#   adding: Tensorflow//models/official/vision/dataloaders/video_input.py (deflated 74%)
#   adding: Tensorflow//models/official/vision/tasks/ (stored 0%)
#   adding: Tensorflow//models/official/vision/tasks/image_classification.py (deflated 73%)
#   adding: Tensorflow//models/official/vision/tasks/video_classification.py (deflated 73%)
#   adding: Tensorflow//models/official/vision/tasks/retinanet.py (deflated 72%)
#   adding: Tensorflow//models/official/vision/tasks/maskrcnn.py (deflated 73%)
#   adding: Tensorflow//models/official/vision/tasks/__init__.py (deflated 49%)
#   adding: Tensorflow//models/official/vision/tasks/semantic_segmentation.py (deflated 71%)
#   adding: Tensorflow//models/official/vision/README.md (deflated 79%)
#   adding: Tensorflow//models/official/vision/serving/ (stored 0%)
#   adding: Tensorflow//models/official/vision/serving/export_saved_model.py (deflated 61%)
#   adding: Tensorflow//models/official/vision/serving/export_module_factory.py (deflated 66%)
#   adding: Tensorflow//models/official/vision/serving/image_classification_test.py (deflated 62%)
#   adding: Tensorflow//models/official/vision/serving/export_tflite_lib.py (deflated 68%)
#   adding: Tensorflow//models/official/vision/serving/semantic_segmentation_test.py (deflated 67%)
#   adding: Tensorflow//models/official/vision/serving/export_saved_model_lib.py (deflated 70%)
#   adding: Tensorflow//models/official/vision/serving/video_classification_test.py (deflated 61%)
#   adding: Tensorflow//models/official/vision/serving/image_classification.py (deflated 56%)
#   adding: Tensorflow//models/official/vision/serving/export_base.py (deflated 71%)
#   adding: Tensorflow//models/official/vision/serving/export_saved_model_lib_test.py (deflated 59%)
#   adding: Tensorflow//models/official/vision/serving/export_tfhub.py (deflated 60%)
#   adding: Tensorflow//models/official/vision/serving/video_classification.py (deflated 70%)
#   adding: Tensorflow//models/official/vision/serving/export_saved_model_lib_v2.py (deflated 63%)
#   adding: Tensorflow//models/official/vision/serving/export_base_v2_test.py (deflated 64%)
#   adding: Tensorflow//models/official/vision/serving/detection_test.py (deflated 69%)
#   adding: Tensorflow//models/official/vision/serving/export_tflite_lib_test.py (deflated 77%)
#   adding: Tensorflow//models/official/vision/serving/export_tflite.py (deflated 59%)
#   adding: Tensorflow//models/official/vision/serving/export_module_factory_test.py (deflated 61%)
#   adding: Tensorflow//models/official/vision/serving/export_base_v2.py (deflated 59%)
#   adding: Tensorflow//models/official/vision/serving/__init__.py (deflated 38%)
#   adding: Tensorflow//models/official/vision/serving/detection.py (deflated 68%)
#   adding: Tensorflow//models/official/vision/serving/export_utils.py (deflated 68%)
#   adding: Tensorflow//models/official/vision/serving/semantic_segmentation.py (deflated 62%)
#   adding: Tensorflow//models/official/vision/examples/ (stored 0%)
#   adding: Tensorflow//models/official/vision/examples/starter/ (stored 0%)
#   adding: Tensorflow//models/official/vision/examples/starter/example_config.py (deflated 65%)
#   adding: Tensorflow//models/official/vision/examples/starter/train.py (deflated 44%)
#   adding: Tensorflow//models/official/vision/examples/starter/example_task.py (deflated 66%)
#   adding: Tensorflow//models/official/vision/examples/starter/example_config_tpu.yaml (deflated 56%)
#   adding: Tensorflow//models/official/vision/examples/starter/example_config_local.yaml (deflated 57%)
#   adding: Tensorflow//models/official/vision/examples/starter/registry_imports.py (deflated 49%)
#   adding: Tensorflow//models/official/vision/examples/starter/example_model.py (deflated 59%)
#   adding: Tensorflow//models/official/vision/examples/starter/README.md (deflated 63%)
#   adding: Tensorflow//models/official/vision/examples/starter/example_input.py (deflated 63%)
#   adding: Tensorflow//models/official/vision/__init__.py (deflated 39%)
#   adding: Tensorflow//models/official/vision/data/ (stored 0%)
#   adding: Tensorflow//models/official/vision/data/process_coco_panoptic.sh (deflated 73%)
#   adding: Tensorflow//models/official/vision/data/tf_example_feature_key.py (deflated 72%)
#   adding: Tensorflow//models/official/vision/data/tf_example_builder.py (deflated 82%)
#   adding: Tensorflow//models/official/vision/data/tf_example_builder_test.py (deflated 89%)
#   adding: Tensorflow//models/official/vision/data/image_utils_test.py (deflated 70%)
#   adding: Tensorflow//models/official/vision/data/process_coco_few_shot.sh (deflated 72%)
#   adding: Tensorflow//models/official/vision/data/fake_feature_generator.py (deflated 66%)
#   adding: Tensorflow//models/official/vision/data/image_utils.py (deflated 58%)
#   adding: Tensorflow//models/official/vision/data/tfrecord_lib.py (deflated 65%)
#   adding: Tensorflow//models/official/vision/data/create_coco_tf_record.py (deflated 75%)
#   adding: Tensorflow//models/official/vision/data/__init__.py (deflated 37%)
#   adding: Tensorflow//models/official/vision/data/process_coco_few_shot_json_files.py (deflated 58%)
#   adding: Tensorflow//models/official/vision/data/tfrecord_lib_test.py (deflated 61%)
#   adding: Tensorflow//models/official/core/ (stored 0%)
#   adding: Tensorflow//models/official/core/config_definitions.py (deflated 65%)
#   adding: Tensorflow//models/official/core/train_lib_test.py (deflated 80%)
#   adding: Tensorflow//models/official/core/tf_example_feature_key.py (deflated 53%)
#   adding: Tensorflow//models/official/core/tf_example_builder.py (deflated 69%)
#   adding: Tensorflow//models/official/core/file_writers_test.py (deflated 57%)
#   adding: Tensorflow//models/official/core/actions_test.py (deflated 68%)
#   adding: Tensorflow//models/official/core/tf_example_builder_test.py (deflated 78%)
#   adding: Tensorflow//models/official/core/base_trainer.py (deflated 73%)
#   adding: Tensorflow//models/official/core/export_base.py (deflated 62%)
#   adding: Tensorflow//models/official/core/tf_example_feature_key_test.py (deflated 55%)
#   adding: Tensorflow//models/official/core/registry_test.py (deflated 66%)
#   adding: Tensorflow//models/official/core/input_reader.py (deflated 75%)
#   adding: Tensorflow//models/official/core/train_lib.py (deflated 74%)
#   adding: Tensorflow//models/official/core/savedmodel_checkpoint_manager_test.py (deflated 64%)
#   adding: Tensorflow//models/official/core/train_utils.py (deflated 70%)
#   adding: Tensorflow//models/official/core/exp_factory.py (deflated 46%)
#   adding: Tensorflow//models/official/core/registry.py (deflated 68%)
#   adding: Tensorflow//models/official/core/test_utils.py (deflated 57%)
#   adding: Tensorflow//models/official/core/actions.py (deflated 69%)
#   adding: Tensorflow//models/official/core/file_writers.py (deflated 64%)
#   adding: Tensorflow//models/official/core/__init__.py (deflated 55%)
#   adding: Tensorflow//models/official/core/base_task.py (deflated 70%)
#   adding: Tensorflow//models/official/core/export_base_test.py (deflated 68%)
#   adding: Tensorflow//models/official/core/base_trainer_test.py (deflated 75%)
#   adding: Tensorflow//models/official/core/savedmodel_checkpoint_manager.py (deflated 70%)
#   adding: Tensorflow//models/official/core/train_utils_test.py (deflated 72%)
#   adding: Tensorflow//models/official/core/task_factory.py (deflated 55%)
#   adding: Tensorflow//models/official/utils/ (stored 0%)
#   adding: Tensorflow//models/official/utils/hyperparams_flags.py (deflated 64%)
#   adding: Tensorflow//models/official/utils/docs/ (stored 0%)
#   adding: Tensorflow//models/official/utils/docs/build_orbit_api_docs.py (deflated 58%)
#   adding: Tensorflow//models/official/utils/docs/build_tfm_api_docs.py (deflated 60%)
#   adding: Tensorflow//models/official/utils/docs/README.md (deflated 36%)
#   adding: Tensorflow//models/official/utils/docs/__init__.py (deflated 37%)
#   adding: Tensorflow//models/official/utils/flags/ (stored 0%)
#   adding: Tensorflow//models/official/utils/flags/guidelines.md (deflated 55%)
#   adding: Tensorflow//models/official/utils/flags/core.py (deflated 61%)
#   adding: Tensorflow//models/official/utils/flags/flags_test.py (deflated 71%)
#   adding: Tensorflow//models/official/utils/flags/_base.py (deflated 68%)
#   adding: Tensorflow//models/official/utils/flags/_distribution.py (deflated 52%)
#   adding: Tensorflow//models/official/utils/flags/_conventions.py (deflated 44%)
#   adding: Tensorflow//models/official/utils/flags/_benchmark.py (deflated 67%)
#   adding: Tensorflow//models/official/utils/flags/_misc.py (deflated 47%)
#   adding: Tensorflow//models/official/utils/flags/_device.py (deflated 56%)
#   adding: Tensorflow//models/official/utils/flags/README.md (deflated 56%)
#   adding: Tensorflow//models/official/utils/flags/__init__.py (deflated 37%)
#   adding: Tensorflow//models/official/utils/flags/_performance.py (deflated 70%)
#   adding: Tensorflow//models/official/utils/misc/ (stored 0%)
#   adding: Tensorflow//models/official/utils/misc/model_helpers_test.py (deflated 71%)
#   adding: Tensorflow//models/official/utils/misc/model_helpers.py (deflated 60%)
#   adding: Tensorflow//models/official/utils/misc/keras_utils.py (deflated 68%)
#   adding: Tensorflow//models/official/utils/misc/__init__.py (deflated 37%)
#   adding: Tensorflow//models/official/utils/testing/ (stored 0%)
#   adding: Tensorflow//models/official/utils/testing/integration.py (deflated 54%)
#   adding: Tensorflow//models/official/utils/testing/mock_task.py (deflated 57%)
#   adding: Tensorflow//models/official/utils/testing/pylint.rcfile (deflated 60%)
#   adding: Tensorflow//models/official/utils/testing/scripts/ (stored 0%)
#   adding: Tensorflow//models/official/utils/testing/scripts/builds_common.sh (deflated 49%)
#   adding: Tensorflow//models/official/utils/testing/scripts/ci_sanity.sh (deflated 57%)
#   adding: Tensorflow//models/official/utils/testing/scripts/presubmit.sh (deflated 48%)
#   adding: Tensorflow//models/official/utils/testing/__init__.py (deflated 37%)
#   adding: Tensorflow//models/official/utils/__init__.py (deflated 37%)
#   adding: Tensorflow//models/official/projects/ (stored 0%)
#   adding: Tensorflow//models/official/projects/basnet/ (stored 0%)
#   adding: Tensorflow//models/official/projects/basnet/evaluation/ (stored 0%)
#   adding: Tensorflow//models/official/projects/basnet/evaluation/metrics_test.py (deflated 59%)
#   adding: Tensorflow//models/official/projects/basnet/evaluation/metrics.py (deflated 77%)
#   adding: Tensorflow//models/official/projects/basnet/train.py (deflated 48%)
#   adding: Tensorflow//models/official/projects/basnet/configs/ (stored 0%)
#   adding: Tensorflow//models/official/projects/basnet/configs/experiments/ (stored 0%)
#   adding: Tensorflow//models/official/projects/basnet/configs/experiments/basnet_dut_gpu.yaml (deflated 39%)
#   adding: Tensorflow//models/official/projects/basnet/configs/basnet.py (deflated 66%)
#   adding: Tensorflow//models/official/projects/basnet/configs/basnet_test.py (deflated 51%)
#   adding: Tensorflow//models/official/projects/basnet/losses/ (stored 0%)
#   adding: Tensorflow//models/official/projects/basnet/losses/basnet_losses.py (deflated 57%)
#   adding: Tensorflow//models/official/projects/basnet/modeling/ (stored 0%)
#   adding: Tensorflow//models/official/projects/basnet/modeling/basnet_model_test.py (deflated 57%)
#   adding: Tensorflow//models/official/projects/basnet/modeling/refunet.py (deflated 67%)
#   adding: Tensorflow//models/official/projects/basnet/modeling/nn_blocks.py (deflated 77%)
#   adding: Tensorflow//models/official/projects/basnet/modeling/basnet_model.py (deflated 74%)
#   adding: Tensorflow//models/official/projects/basnet/tasks/ (stored 0%)
#   adding: Tensorflow//models/official/projects/basnet/tasks/basnet.py (deflated 70%)
#   adding: Tensorflow//models/official/projects/basnet/README.md (deflated 52%)
#   adding: Tensorflow//models/official/projects/basnet/serving/ (stored 0%)
#   adding: Tensorflow//models/official/projects/basnet/serving/export_saved_model.py (deflated 60%)
#   adding: Tensorflow//models/official/projects/basnet/serving/basnet.py (deflated 51%)
#   adding: Tensorflow//models/official/projects/unified_detector/ (stored 0%)
#   adding: Tensorflow//models/official/projects/unified_detector/external_configurables.py (deflated 40%)
#   adding: Tensorflow//models/official/projects/unified_detector/docs/ (stored 0%)
#   adding: Tensorflow//models/official/projects/unified_detector/docs/images/ (stored 0%)
#   adding: Tensorflow//models/official/projects/unified_detector/docs/images/task.png (deflated 0%)
#   adding: Tensorflow//models/official/projects/unified_detector/utils/ (stored 0%)
#   adding: Tensorflow//models/official/projects/unified_detector/utils/typing.py (deflated 44%)
#   adding: Tensorflow//models/official/projects/unified_detector/utils/utilities.py (deflated 65%)
#   adding: Tensorflow//models/official/projects/unified_detector/train.py (deflated 56%)
#   adding: Tensorflow//models/official/projects/unified_detector/data_loaders/ (stored 0%)
#   adding: Tensorflow//models/official/projects/unified_detector/data_loaders/tf_example_decoder.py (deflated 72%)
#   adding: Tensorflow//models/official/projects/unified_detector/data_loaders/input_reader.py (deflated 68%)
#   adding: Tensorflow//models/official/projects/unified_detector/data_loaders/universal_detection_parser.py (deflated 72%)
#   adding: Tensorflow//models/official/projects/unified_detector/data_loaders/autoaugment.py (deflated 70%)
#   adding: Tensorflow//models/official/projects/unified_detector/configs/ (stored 0%)
#   adding: Tensorflow//models/official/projects/unified_detector/configs/gin_files/ (stored 0%)
#   adding: Tensorflow//models/official/projects/unified_detector/configs/gin_files/unified_detector_model.gin (deflated 60%)
#   adding: Tensorflow//models/official/projects/unified_detector/configs/gin_files/unified_detector_train.gin (deflated 55%)
#   adding: Tensorflow//models/official/projects/unified_detector/configs/ocr_config.py (deflated 62%)
#   adding: Tensorflow//models/official/projects/unified_detector/registry_imports.py (deflated 45%)
#   adding: Tensorflow//models/official/projects/unified_detector/requirements.txt (deflated 16%)
#   adding: Tensorflow//models/official/projects/unified_detector/modeling/ (stored 0%)
#   adding: Tensorflow//models/official/projects/unified_detector/modeling/universal_detector.py (deflated 72%)
#   adding: Tensorflow//models/official/projects/unified_detector/tasks/ (stored 0%)
#   adding: Tensorflow//models/official/projects/unified_detector/tasks/ocr_task.py (deflated 59%)
#   adding: Tensorflow//models/official/projects/unified_detector/tasks/all_models.py (deflated 39%)
#   adding: Tensorflow//models/official/projects/unified_detector/README.md (deflated 62%)
#   adding: Tensorflow//models/official/projects/unified_detector/data_conversion/ (stored 0%)
#   adding: Tensorflow//models/official/projects/unified_detector/data_conversion/utils.py (deflated 64%)
#   adding: Tensorflow//models/official/projects/unified_detector/data_conversion/convert.py (deflated 51%)
#   adding: Tensorflow//models/official/projects/unified_detector/run_inference.py (deflated 62%)
#   adding: Tensorflow//models/official/projects/s3d/ (stored 0%)
#   adding: Tensorflow//models/official/projects/s3d/train.py (deflated 47%)
#   adding: Tensorflow//models/official/projects/s3d/configs/ (stored 0%)
#   adding: Tensorflow//models/official/projects/s3d/configs/s3d.py (deflated 60%)
#   adding: Tensorflow//models/official/projects/s3d/modeling/ (stored 0%)
#   adding: Tensorflow//models/official/projects/s3d/modeling/s3d.py (deflated 73%)
#   adding: Tensorflow//models/official/projects/s3d/modeling/net_utils.py (deflated 77%)
#   adding: Tensorflow//models/official/projects/s3d/modeling/s3d_test.py (deflated 63%)
#   adding: Tensorflow//models/official/projects/s3d/modeling/inception_utils_test.py (deflated 63%)
#   adding: Tensorflow//models/official/projects/s3d/modeling/inception_utils.py (deflated 80%)
#   adding: Tensorflow//models/official/projects/s3d/modeling/net_utils_test.py (deflated 61%)
#   adding: Tensorflow//models/official/projects/text_classification_example/ (stored 0%)
#   adding: Tensorflow//models/official/projects/text_classification_example/experiments/ (stored 0%)
#   adding: Tensorflow//models/official/projects/text_classification_example/experiments/classification_ft_cola.yaml (deflated 59%)
#   adding: Tensorflow//models/official/projects/text_classification_example/experiments/local_example.yaml (deflated 57%)
#   adding: Tensorflow//models/official/projects/text_classification_example/classification_data_loader.py (deflated 58%)
#   adding: Tensorflow//models/official/projects/text_classification_example/train.py (deflated 56%)
#   adding: Tensorflow//models/official/projects/text_classification_example/classification_example_test.py (deflated 58%)
#   adding: Tensorflow//models/official/projects/text_classification_example/classification_example.py (deflated 66%)
#   adding: Tensorflow//models/official/projects/text_classification_example/README.md (deflated 57%)
#   adding: Tensorflow//models/official/projects/qat/ (stored 0%)
#   adding: Tensorflow//models/official/projects/qat/vision/ (stored 0%)
#   adding: Tensorflow//models/official/projects/qat/vision/train.py (deflated 41%)
#   adding: Tensorflow//models/official/projects/qat/vision/quantization/ (stored 0%)
#   adding: Tensorflow//models/official/projects/qat/vision/quantization/configs.py (deflated 77%)
#   adding: Tensorflow//models/official/projects/qat/vision/quantization/layer_transforms.py (deflated 68%)
#   adding: Tensorflow//models/official/projects/qat/vision/quantization/helper_test.py (deflated 55%)
#   adding: Tensorflow//models/official/projects/qat/vision/quantization/helper.py (deflated 70%)
#   adding: Tensorflow//models/official/projects/qat/vision/quantization/configs_test.py (deflated 75%)
#   adding: Tensorflow//models/official/projects/qat/vision/quantization/__init__.py (deflated 37%)
#   adding: Tensorflow//models/official/projects/qat/vision/quantization/schemes.py (deflated 64%)
#   adding: Tensorflow//models/official/projects/qat/vision/configs/ (stored 0%)
#   adding: Tensorflow//models/official/projects/qat/vision/configs/experiments/ (stored 0%)
#   adding: Tensorflow//models/official/projects/qat/vision/configs/experiments/image_classification/ (stored 0%)
#   adding: Tensorflow//models/official/projects/qat/vision/configs/experiments/image_classification/imagenet_mobilenetv3.5_qat_gpu.yaml (deflated 54%)
#   adding: Tensorflow//models/official/projects/qat/vision/configs/experiments/image_classification/imagenet_mobilenetv3large_qat_tpu.yaml (deflated 56%)
#   adding: Tensorflow//models/official/projects/qat/vision/configs/experiments/image_classification/imagenet_resnet50_qat_gpu_fast_4x8.yaml (deflated 56%)
#   adding: Tensorflow//models/official/projects/qat/vision/configs/experiments/image_classification/imagenet_resnet50_qat_gpu_fast_4x4.yaml (deflated 56%)
#   adding: Tensorflow//models/official/projects/qat/vision/configs/experiments/image_classification/imagenet_mobilenetv2_qat_gpu_batch512.yaml (deflated 55%)
#   adding: Tensorflow//models/official/projects/qat/vision/configs/experiments/image_classification/imagenet_resnet50_qat_gpu_fast_6x6.yaml (deflated 56%)
#   adding: Tensorflow//models/official/projects/qat/vision/configs/experiments/image_classification/imagenet_resnet50_qat_gpu_fast.yaml (deflated 56%)
#   adding: Tensorflow//models/official/projects/qat/vision/configs/experiments/image_classification/imagenet_mobilenetv2_qat_gpu.yaml (deflated 55%)
#   adding: Tensorflow//models/official/projects/qat/vision/configs/experiments/image_classification/imagenet_resnet50_qat_gpu.yaml (deflated 54%)
#   adding: Tensorflow//models/official/projects/qat/vision/configs/experiments/image_classification/imagenet_mobilenetv2_qat_gpu_batch256.yaml (deflated 55%)
#   adding: Tensorflow//models/official/projects/qat/vision/configs/experiments/retinanet/ (stored 0%)
#   adding: Tensorflow//models/official/projects/qat/vision/configs/experiments/retinanet/coco_mobilenetv2_qat_tpu_e2e.yaml (deflated 56%)
#   adding: Tensorflow//models/official/projects/qat/vision/configs/experiments/retinanet/coco_spinenet49_mobile_qat_gpu.yaml (deflated 55%)
#   adding: Tensorflow//models/official/projects/qat/vision/configs/experiments/retinanet/coco_spinenet49_mobile_qat_tpu_e2e.yaml (deflated 53%)
#   adding: Tensorflow//models/official/projects/qat/vision/configs/experiments/retinanet/coco_spinenet49_mobile_qat_tpu.yaml (deflated 53%)
#   adding: Tensorflow//models/official/projects/qat/vision/configs/experiments/semantic_segmentation/ (stored 0%)
#   adding: Tensorflow//models/official/projects/qat/vision/configs/experiments/semantic_segmentation/deeplabv3plus_mobilenetv2_cityscapes_qat_tpu.yaml (deflated 59%)
#   adding: Tensorflow//models/official/projects/qat/vision/configs/experiments/semantic_segmentation/deeplabv3_mobilenetv2_pascal_qat_tpu.yaml (deflated 58%)
#   adding: Tensorflow//models/official/projects/qat/vision/configs/experiments/semantic_segmentation/deeplabv3_mobilenetv2_pascal_qat_gpu.yaml (deflated 58%)
#   adding: Tensorflow//models/official/projects/qat/vision/configs/image_classification_test.py (deflated 56%)
#   adding: Tensorflow//models/official/projects/qat/vision/configs/retinanet_test.py (deflated 55%)
#   adding: Tensorflow//models/official/projects/qat/vision/configs/semantic_segmentation_test.py (deflated 57%)
#   adding: Tensorflow//models/official/projects/qat/vision/configs/common.py (deflated 55%)
#   adding: Tensorflow//models/official/projects/qat/vision/configs/image_classification.py (deflated 61%)
#   adding: Tensorflow//models/official/projects/qat/vision/configs/retinanet.py (deflated 51%)
#   adding: Tensorflow//models/official/projects/qat/vision/configs/__init__.py (deflated 44%)
#   adding: Tensorflow//models/official/projects/qat/vision/configs/semantic_segmentation.py (deflated 66%)
#   adding: Tensorflow//models/official/projects/qat/vision/registry_imports.py (deflated 48%)
#   adding: Tensorflow//models/official/projects/qat/vision/n_bit/ (stored 0%)
#   adding: Tensorflow//models/official/projects/qat/vision/n_bit/configs.py (deflated 79%)
#   adding: Tensorflow//models/official/projects/qat/vision/n_bit/nn_blocks.py (deflated 84%)
#   adding: Tensorflow//models/official/projects/qat/vision/n_bit/nn_layers.py (deflated 72%)
#   adding: Tensorflow//models/official/projects/qat/vision/n_bit/configs_test.py (deflated 78%)
#   adding: Tensorflow//models/official/projects/qat/vision/n_bit/__init__.py (deflated 51%)
#   adding: Tensorflow//models/official/projects/qat/vision/n_bit/nn_blocks_test.py (deflated 68%)
# ...
#   adding: Tensorflow//workspace/images/test/139.png (deflated 16%)
#   adding: Tensorflow//workspace/images/test/139.xml (deflated 89%)
#   adding: Tensorflow//workspace/images/test/124.jpg (deflated 19%)
#   adding: Tensorflow//workspace/images/test/132.png (deflated 30%)
#   adding: Tensorflow//workspace/images/test/121.png (deflated 31%)
#   adding: Tensorflow//workspace/images/test/116.xml (deflated 85%)
#   adding: Tensorflow//workspace/images/test/136.png (deflated 28%)
#   adding: Tensorflow//workspace/images/test/114.xml (deflated 87%)
#   adding: Tensorflow//workspace/images/test/119.png (deflated 27%)
#   adding: Tensorflow//workspace/images/test/117.xml (deflated 88%)
#   adding: Tensorflow//workspace/images/test/124.xml (deflated 88%)
#   adding: Tensorflow//workspace/images/test/111.xml (deflated 87%)
#   adding: Tensorflow//workspace/images/test/113.png (deflated 40%)
#   adding: Tensorflow//workspace/images/test/140.xml (deflated 86%)
#   adding: Tensorflow//workspace/images/test/112.png (deflated 32%)
#   adding: Tensorflow//workspace/images/test/125.xml (deflated 89%)
#   adding: Tensorflow//workspace/images/test/130.xml (deflated 87%)
#   adding: Tensorflow//workspace/images/test/120.xml (deflated 86%)
#   adding: Tensorflow//workspace/images/test/122.png (deflated 31%)
#   adding: Tensorflow//workspace/images/test/111.png (deflated 30%)
#   adding: Tensorflow//workspace/images/test/127.xml (deflated 79%)
#   adding: Tensorflow//workspace/images/test/128.xml (deflated 87%)
#   adding: Tensorflow//workspace/images/test/130.jpg (deflated 32%)
#   adding: Tensorflow//workspace/images/test/120.png (deflated 29%)
#   adding: Tensorflow//workspace/images/test/121.xml (deflated 84%)
#   adding: Tensorflow//workspace/images/.ipynb_checkpoints/ (stored 0%)
#   adding: Tensorflow//workspace/images/train/ (stored 0%)
#   adding: Tensorflow//workspace/images/train/001.png (deflated 20%)
#   adding: Tensorflow//workspace/images/train/006.png (deflated 32%)
#   adding: Tensorflow//workspace/images/train/005.png (deflated 15%)
#   adding: Tensorflow//workspace/images/train/007.xml (deflated 86%)
#   adding: Tensorflow//workspace/images/train/099.png (deflated 26%)
#   adding: Tensorflow//workspace/images/train/068.png (deflated 34%)
#   adding: Tensorflow//workspace/images/train/054.png (deflated 37%)
#   adding: Tensorflow//workspace/images/train/083.xml (deflated 89%)
#   adding: Tensorflow//workspace/images/train/087.xml (deflated 89%)
#   adding: Tensorflow//workspace/images/train/105.xml (deflated 82%)
#   adding: Tensorflow//workspace/images/train/047.png (deflated 18%)
#   adding: Tensorflow//workspace/images/train/073.png (deflated 26%)
#   adding: Tensorflow//workspace/images/train/051.png (deflated 41%)
#   adding: Tensorflow//workspace/images/train/087.png (deflated 28%)
#   adding: Tensorflow//workspace/images/train/027.xml (deflated 89%)
#   adding: Tensorflow//workspace/images/train/041.xml (deflated 89%)
#   adding: Tensorflow//workspace/images/train/063.png (deflated 30%)
#   adding: Tensorflow//workspace/images/train/088.xml (deflated 87%)
#   adding: Tensorflow//workspace/images/train/098.png (deflated 15%)
#   adding: Tensorflow//workspace/images/train/012.xml (deflated 89%)
#   adding: Tensorflow//workspace/images/train/085.xml (deflated 84%)
#   adding: Tensorflow//workspace/images/train/069.xml (deflated 87%)
#   adding: Tensorflow//workspace/images/train/029.xml (deflated 85%)
#   adding: Tensorflow//workspace/images/train/092.png (deflated 11%)
#   adding: Tensorflow//workspace/images/train/082.xml (deflated 87%)
#   adding: Tensorflow//workspace/images/train/101.png (deflated 22%)
#   adding: Tensorflow//workspace/images/train/108.png (deflated 23%)
#   adding: Tensorflow//workspace/images/train/063.xml (deflated 89%)
#   adding: Tensorflow//workspace/images/train/042.xml (deflated 86%)
#   adding: Tensorflow//workspace/images/train/070.png (deflated 33%)
#   adding: Tensorflow//workspace/images/train/076.png (deflated 36%)
#   adding: Tensorflow//workspace/images/train/015.xml (deflated 86%)
#   adding: Tensorflow//workspace/images/train/044.png (deflated 36%)
#   adding: Tensorflow//workspace/images/train/076.xml (deflated 85%)
#   adding: Tensorflow//workspace/images/train/021.xml (deflated 85%)
#   adding: Tensorflow//workspace/images/train/037.xml (deflated 89%)
#   adding: Tensorflow//workspace/images/train/110.xml (deflated 85%)
#   adding: Tensorflow//workspace/images/train/034.png (deflated 33%)
#   adding: Tensorflow//workspace/images/train/040.xml (deflated 86%)
#   adding: Tensorflow//workspace/images/train/049.png (deflated 36%)
#   adding: Tensorflow//workspace/images/train/048.png (deflated 34%)
#   adding: Tensorflow//workspace/images/train/060.xml (deflated 85%)
#   adding: Tensorflow//workspace/images/train/095.xml (deflated 85%)
#   adding: Tensorflow//workspace/images/train/033.xml (deflated 86%)
#   adding: Tensorflow//workspace/images/train/059.xml (deflated 86%)
#   adding: Tensorflow//workspace/images/train/023.png (deflated 22%)
#   adding: Tensorflow//workspace/images/train/020.png (deflated 21%)
#   adding: Tensorflow//workspace/images/train/036.xml (deflated 88%)
#   adding: Tensorflow//workspace/images/train/067.xml (deflated 86%)
#   adding: Tensorflow//workspace/images/train/050.png (deflated 25%)
#   adding: Tensorflow//workspace/images/train/034.xml (deflated 86%)
#   adding: Tensorflow//workspace/images/train/100.xml (deflated 85%)
#   adding: Tensorflow//workspace/images/train/002.xml (deflated 87%)
#   adding: Tensorflow//workspace/images/train/018.xml (deflated 88%)
#   adding: Tensorflow//workspace/images/train/060.png (deflated 26%)
#   adding: Tensorflow//workspace/images/train/009.xml (deflated 88%)
#   adding: Tensorflow//workspace/images/train/031.xml (deflated 87%)
#   adding: Tensorflow//workspace/images/train/009.png (deflated 28%)
#   adding: Tensorflow//workspace/images/train/019.png (deflated 26%)
#   adding: Tensorflow//workspace/images/train/053.png (deflated 18%)
#   adding: Tensorflow//workspace/images/train/025.png (deflated 32%)
#   adding: Tensorflow//workspace/images/train/008.xml (deflated 84%)
#   adding: Tensorflow//workspace/images/train/061.xml (deflated 86%)
#   adding: Tensorflow//workspace/images/train/028.xml (deflated 86%)
#   adding: Tensorflow//workspace/images/train/064.png (deflated 28%)
#   adding: Tensorflow//workspace/images/train/080.png (deflated 38%)
#   adding: Tensorflow//workspace/images/train/096.xml (deflated 89%)
#   adding: Tensorflow//workspace/images/train/077.xml (deflated 88%)
#   adding: Tensorflow//workspace/images/train/055.png (deflated 16%)
#   adding: Tensorflow//workspace/images/train/097.png (deflated 36%)
#   adding: Tensorflow//workspace/images/train/032.xml (deflated 86%)
#   adding: Tensorflow//workspace/images/train/065.xml (deflated 88%)
#   adding: Tensorflow//workspace/images/train/101.xml (deflated 83%)
#   adding: Tensorflow//workspace/images/train/046.xml (deflated 75%)
#   adding: Tensorflow//workspace/images/train/019.xml (deflated 85%)
#   adding: Tensorflow//workspace/images/train/100.png (deflated 53%)
#   adding: Tensorflow//workspace/images/train/057.png (deflated 25%)
#   adding: Tensorflow//workspace/images/train/006.xml (deflated 83%)
#   adding: Tensorflow//workspace/images/train/017.xml (deflated 83%)
#   adding: Tensorflow//workspace/images/train/106.xml (deflated 87%)
#   adding: Tensorflow//workspace/images/train/077.png (deflated 26%)
#   adding: Tensorflow//workspace/images/train/029.png (deflated 33%)
#   adding: Tensorflow//workspace/images/train/058.png (deflated 36%)
#   adding: Tensorflow//workspace/images/train/007.png (deflated 33%)
#   adding: Tensorflow//workspace/images/train/058.xml (deflated 85%)
#   adding: Tensorflow//workspace/images/train/095.png (deflated 42%)
#   adding: Tensorflow//workspace/images/train/025.xml (deflated 84%)
#   adding: Tensorflow//workspace/images/train/073.xml (deflated 88%)
#   adding: Tensorflow//workspace/images/train/043.png (deflated 2%)
#   adding: Tensorflow//workspace/images/train/013.png (deflated 20%)
#   adding: Tensorflow//workspace/images/train/107.png (deflated 30%)
#   adding: Tensorflow//workspace/images/train/035.png (deflated 29%)
#   adding: Tensorflow//workspace/images/train/082.png (deflated 27%)
#   adding: Tensorflow//workspace/images/train/081.xml (deflated 87%)
#   adding: Tensorflow//workspace/images/train/070.xml (deflated 88%)
#   adding: Tensorflow//workspace/images/train/014.png (deflated 33%)
#   adding: Tensorflow//workspace/images/train/094.xml (deflated 85%)
#   adding: Tensorflow//workspace/images/train/062.xml (deflated 87%)
#   adding: Tensorflow//workspace/images/train/086.xml (deflated 85%)
#   adding: Tensorflow//workspace/images/train/026.png (deflated 28%)
#   adding: Tensorflow//workspace/images/train/013.xml (deflated 88%)
#   adding: Tensorflow//workspace/images/train/018.png (deflated 28%)
#   adding: Tensorflow//workspace/images/train/093.png (deflated 32%)
#   adding: Tensorflow//workspace/images/train/046.png (deflated 23%)
#   adding: Tensorflow//workspace/images/train/104.png (deflated 31%)
#   adding: Tensorflow//workspace/images/train/092.xml (deflated 87%)
#   adding: Tensorflow//workspace/images/train/005.xml (deflated 86%)
#   adding: Tensorflow//workspace/images/train/090.xml (deflated 87%)
#   adding: Tensorflow//workspace/images/train/109.xml (deflated 88%)
#   adding: Tensorflow//workspace/images/train/012.png (deflated 39%)
#   adding: Tensorflow//workspace/images/train/026.xml (deflated 86%)
#   adding: Tensorflow//workspace/images/train/075.xml (deflated 85%)
#   adding: Tensorflow//workspace/images/train/054.xml (deflated 86%)
#   adding: Tensorflow//workspace/images/train/030.png (deflated 29%)
#   adding: Tensorflow//workspace/images/train/016.png (deflated 26%)
#   adding: Tensorflow//workspace/images/train/109.png (deflated 20%)
#   adding: Tensorflow//workspace/images/train/039.png (deflated 7%)
#   adding: Tensorflow//workspace/images/train/052.xml (deflated 87%)
#   adding: Tensorflow//workspace/images/train/103.xml (deflated 86%)
#   adding: Tensorflow//workspace/images/train/086.png (deflated 52%)
#   adding: Tensorflow//workspace/images/train/001.xml (deflated 85%)
#   adding: Tensorflow//workspace/images/train/078.png (deflated 30%)
#   adding: Tensorflow//workspace/images/train/093.xml (deflated 84%)
#   adding: Tensorflow//workspace/images/train/048.xml (deflated 88%)
#   adding: Tensorflow//workspace/images/train/059.png (deflated 29%)
#   adding: Tensorflow//workspace/images/train/021.png (deflated 26%)
#   adding: Tensorflow//workspace/images/train/016.xml (deflated 80%)
#   adding: Tensorflow//workspace/images/train/097.xml (deflated 86%)
#   adding: Tensorflow//workspace/images/train/075.png (deflated 10%)
#   adding: Tensorflow//workspace/images/train/079.xml (deflated 87%)
#   adding: Tensorflow//workspace/images/train/062.png (deflated 30%)
#   adding: Tensorflow//workspace/images/train/055.xml (deflated 87%)
#   adding: Tensorflow//workspace/images/train/081.png (deflated 27%)
#   adding: Tensorflow//workspace/images/train/096.png (deflated 22%)
#   adding: Tensorflow//workspace/images/train/079.png (deflated 36%)
#   adding: Tensorflow//workspace/images/train/045.png (deflated 36%)
#   adding: Tensorflow//workspace/images/train/040.png (deflated 25%)
#   adding: Tensorflow//workspace/images/train/052.png (deflated 39%)
#   adding: Tensorflow//workspace/images/train/038.png (deflated 26%)
#   adding: Tensorflow//workspace/images/train/103.png (deflated 29%)
#   adding: Tensorflow//workspace/images/train/094.png (deflated 42%)
#   adding: Tensorflow//workspace/images/train/057.xml (deflated 89%)
#   adding: Tensorflow//workspace/images/train/065.png (deflated 40%)
#   adding: Tensorflow//workspace/images/train/085.png (deflated 31%)
#   adding: Tensorflow//workspace/images/train/028.png (deflated 26%)
#   adding: Tensorflow//workspace/images/train/056.xml (deflated 87%)
#   adding: Tensorflow//workspace/images/train/067.png (deflated 31%)
#   adding: Tensorflow//workspace/images/train/017.png (deflated 27%)
#   adding: Tensorflow//workspace/images/train/072.png (deflated 31%)
#   adding: Tensorflow//workspace/images/train/023.xml (deflated 84%)
#   adding: Tensorflow//workspace/images/train/044.xml (deflated 88%)
#   adding: Tensorflow//workspace/images/train/037.png (deflated 33%)
#   adding: Tensorflow//workspace/images/train/105.png (deflated 30%)
#   adding: Tensorflow//workspace/images/train/078.xml (deflated 84%)
#   adding: Tensorflow//workspace/images/train/043.xml (deflated 89%)
#   adding: Tensorflow//workspace/images/train/010.png (deflated 30%)
#   adding: Tensorflow//workspace/images/train/108.xml (deflated 86%)
#   adding: Tensorflow//workspace/images/train/033.png (deflated 31%)
#   adding: Tensorflow//workspace/images/train/064.xml (deflated 86%)
#   adding: Tensorflow//workspace/images/train/002.png (deflated 12%)
#   adding: Tensorflow//workspace/images/train/049.xml (deflated 89%)
#   adding: Tensorflow//workspace/images/train/035.xml (deflated 87%)
#   adding: Tensorflow//workspace/images/train/107.xml (deflated 89%)
#   adding: Tensorflow//workspace/images/train/090.png (deflated 29%)
#   adding: Tensorflow//workspace/images/train/099.xml (deflated 86%)
#   adding: Tensorflow//workspace/images/train/032.png (deflated 28%)
#   adding: Tensorflow//workspace/images/train/088.png (deflated 24%)
#   adding: Tensorflow//workspace/images/train/080.xml (deflated 87%)
#   adding: Tensorflow//workspace/images/train/056.png (deflated 27%)
#   adding: Tensorflow//workspace/images/train/061.png (deflated 17%)
#   adding: Tensorflow//workspace/images/train/106.png (deflated 22%)
#   adding: Tensorflow//workspace/images/train/022.png (deflated 29%)
#   adding: Tensorflow//workspace/images/train/045.xml (deflated 85%)
#   adding: Tensorflow//workspace/images/train/024.png (deflated 20%)
#   adding: Tensorflow//workspace/images/train/004.png (deflated 25%)
#   adding: Tensorflow//workspace/images/train/089.xml (deflated 85%)
#   adding: Tensorflow//workspace/images/train/072.xml (deflated 85%)
#   adding: Tensorflow//workspace/images/train/010.xml (deflated 88%)
#   adding: Tensorflow//workspace/images/train/047.xml (deflated 87%)
#   adding: Tensorflow//workspace/images/train/083.png (deflated 25%)
#   adding: Tensorflow//workspace/images/train/038.xml (deflated 84%)
#   adding: Tensorflow//workspace/images/train/015.png (deflated 27%)
#   adding: Tensorflow//workspace/images/train/008.png (deflated 26%)
#   adding: Tensorflow//workspace/images/train/011.xml (deflated 88%)
#   adding: Tensorflow//workspace/images/train/068.xml (deflated 86%)
#   adding: Tensorflow//workspace/images/train/027.png (deflated 21%)
#   adding: Tensorflow//workspace/images/train/014.xml (deflated 86%)
#   adding: Tensorflow//workspace/images/train/022.xml (deflated 86%)
#   adding: Tensorflow//workspace/images/train/003.png (deflated 9%)
#   adding: Tensorflow//workspace/images/train/030.xml (deflated 86%)
#   adding: Tensorflow//workspace/images/train/104.xml (deflated 86%)
#   adding: Tensorflow//workspace/images/train/041.png (deflated 18%)
#   adding: Tensorflow//workspace/images/train/051.xml (deflated 85%)
#   adding: Tensorflow//workspace/images/train/110.png (deflated 30%)
#   adding: Tensorflow//workspace/images/train/053.xml (deflated 87%)
#   adding: Tensorflow//workspace/images/train/089.png (deflated 29%)
#   adding: Tensorflow//workspace/images/train/098.xml (deflated 84%)
#   adding: Tensorflow//workspace/images/train/024.xml (deflated 86%)
#   adding: Tensorflow//workspace/images/train/039.xml (deflated 88%)
#   adding: Tensorflow//workspace/images/train/020.xml (deflated 89%)
#   adding: Tensorflow//workspace/images/train/050.xml (deflated 85%)
#   adding: Tensorflow//workspace/images/train/011.png (deflated 25%)
#   adding: Tensorflow//workspace/images/train/004.xml (deflated 88%)
#   adding: Tensorflow//workspace/images/train/069.png (deflated 31%)
#   adding: Tensorflow//workspace/images/train/003.xml (deflated 81%)
#   adding: Tensorflow//workspace/images/train/036.png (deflated 5%)
#   adding: Tensorflow//workspace/images/train/031.png (deflated 40%)
#   adding: Tensorflow//workspace/images/train/042.png (deflated 15%)
